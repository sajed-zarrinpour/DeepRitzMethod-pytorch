# %%
% matplotlib inline
import numpy as np

# Load the dataset
test = np.loadtxt('test.csv', delimiter=',')
train = np.loadtxt('train.csv', delimiter=',')
# split both sets into X (input / data) and Y (output / lables) parts
data = np.array(train)[:,0:2]
labels = np.array(train)[:,2]

d_test = np.array(test)[:,0:2]
l_test = np.array(test)[:,2]

# %%
import torch 
import torch.nn.functional as F
import numpy as np
from math import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm

torch.set_default_tensor_type('torch.FloatTensor')


number_of_residual_blocks = 3 #for each block we have two block, that leaves us with 2*nrb + 1 layer
# \etha
learning_rate = 0.01
#
iterations = 100  #default 10000
#number of iterations before calculating the error
print_every_iter = 100
m=10

# Define our deep Ritz network model
class DeepRitzNet(torch.nn.Module):
    def __init__(self, m):
        super(DeepRitzNet, self).__init__()
        #self.layers = []
        #for i in range(2*number_of_residual_blocks):
        #    self.layers.append(torch.nn.Linear(m,m))
        
        #self.layers.append(torch.nn.Linear(m,1))
        self.linear1 = torch.nn.Linear(m,m)
        self.linear2 = torch.nn.Linear(m,m)
        self.linear3 = torch.nn.Linear(m,m)
        self.linear4 = torch.nn.Linear(m,m)
        self.linear5 = torch.nn.Linear(m,m)
        self.linear6 = torch.nn.Linear(m,m)
        
        self.linear7 = torch.nn.Linear(m,1)
        
    def forward(self, x):
        y = x
        #for i in range(number_of_residual_blocks-1):
        #    y = y+ F.relu(self.layers[i+1](F.relu(self.layers[i])))
        #output = F.relu(self.linear[number_of_residual_blocks+1](y))
        y = y + F.relu(self.linear2(F.relu(self.linear1(y)**3))**3)
        y = y + F.relu(self.linear4(F.relu(self.linear3(y)**3))**3)
        y = y + F.relu(self.linear6(F.relu(self.linear5(y)**3))**3)
        output = F.relu(self.linear7(y)**3)
        return output

# %%
model = DeepRitzNet(m)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

xs = torch.tensor(data[:,0])
ys = torch.tensor(data[:,1])

xl = len(xs)

lr1 = 0.01
lr2 = 0.005

optimizer1 = torch.optim.Adam(model.parameters(), lr=lr1)
optimizer2 = torch.optim.Adam(model.parameters(), lr=lr2)

# %%
# Training
for k in range(iterations):
    loss = torch.zeros(1)
    for i in range(len(xs)):      
        x_input = np.zeros(m)
        x_input[0] = xs[i]
        x_input[1] = ys[i]

        x_input = torch.tensor(x_input).float()
        #y = model(x_input)
        y=labels[i]
        #Note that here we do the zero padding!
        x1 = torch.zeros(m)
        x2 = torch.zeros(m)
        x1[0] = 0.0001
        x2[1] = 0.0001
        x_input_1 = x_input.float() + x1 # E
        x_input_2 = x_input.float() + x2 # N
        x_input_3 = x_input.float() - x1 # W
        x_input_4 = x_input.float() - x2 # S
        #the two point formula to approximate the derivative:
        # f'(x) = f(x+h)-x/h
        
        # WRT x
        #x_input_grad_1 = (model(x_input_1) - y) / 0.0001 
        # WRT y
        #x_input_grad_2 = (model(x_input_2) - y) / 0.0001
        #the two point formula for approximating the second derivative
        #f''(x) = f(x+h) -2*f(x) - f(x-h) / h^2
        
        # WRT x
        x_input_2_grad_x = (model(x_input_1) + model(x_input_3) - 2 * y) / 0.0001**2
        
        # WRT y
        x_input_2_grad_y = (model(x_input_2) + model(x_input_4) - 2 * y) / 0.0001**2

        # loss = 1/N\sigma_{j=1}^{N} 1/2 * |\nabla(u)| - f * u   (f=1) 
        loss += 0.5 * ((x_input_2_grad_x) ** 2 + (x_input_2_grad_y) ** 2) - y
        #print(loss)
                
    loss /= (xl)

    print(k, " epoch, loss: ", loss.data[0].numpy())

    
    #and step the optimizer
    optimizer1.zero_grad()
    optimizer2.zero_grad()
    loss.backward()
    if k < 270:
        optimizer1.step()
    else:
        optimizer2.step()
# Out:
# (0, ' epoch, loss: ', array(6.4731365e+13, dtype=float32))
# (1, ' epoch, loss: ', array(6.2390436e+13, dtype=float32))
# (2, ' epoch, loss: ', array(5.9204757e+13, dtype=float32))
# (3, ' epoch, loss: ', array(5.524326e+13, dtype=float32))
# (4, ' epoch, loss: ', array(5.0850416e+13, dtype=float32))
# (5, ' epoch, loss: ', array(4.693505e+13, dtype=float32))
# (6, ' epoch, loss: ', array(4.521666e+13, dtype=float32))
# (7, ' epoch, loss: ', array(4.6324766e+13, dtype=float32))
# (8, ' epoch, loss: ', array(4.7275775e+13, dtype=float32))
# (9, ' epoch, loss: ', array(4.6056595e+13, dtype=float32))
# (10, ' epoch, loss: ', array(4.385136e+13, dtype=float32))
# (11, ' epoch, loss: ', array(4.2027715e+13, dtype=float32))
# (12, ' epoch, loss: ', array(4.1005747e+13, dtype=float32))
# (13, ' epoch, loss: ', array(4.0545137e+13, dtype=float32))
# (14, ' epoch, loss: ', array(4.0241558e+13, dtype=float32))
# (15, ' epoch, loss: ', array(3.980043e+13, dtype=float32))
# (16, ' epoch, loss: ', array(3.9088132e+13, dtype=float32))
# (17, ' epoch, loss: ', array(3.810047e+13, dtype=float32))
# (18, ' epoch, loss: ', array(3.6927894e+13, dtype=float32))
# (19, ' epoch, loss: ', array(3.5728206e+13, dtype=float32))
# (20, ' epoch, loss: ', array(3.4678925e+13, dtype=float32))
# (21, ' epoch, loss: ', array(3.3882573e+13, dtype=float32))
# (22, ' epoch, loss: ', array(3.3265478e+13, dtype=float32))
# (23, ' epoch, loss: ', array(3.2562236e+13, dtype=float32))
# (24, ' epoch, loss: ', array(3.1554034e+13, dtype=float32))
# (25, ' epoch, loss: ', array(3.0322333e+13, dtype=float32))
# (26, ' epoch, loss: ', array(2.9125643e+13, dtype=float32))
# (27, ' epoch, loss: ', array(2.8106455e+13, dtype=float32))
# (28, ' epoch, loss: ', array(2.7203463e+13, dtype=float32))
# (29, ' epoch, loss: ', array(2.6260546e+13, dtype=float32))
# (30, ' epoch, loss: ', array(2.5170194e+13, dtype=float32))
# (31, ' epoch, loss: ', array(2.3961696e+13, dtype=float32))
# (32, ' epoch, loss: ', array(2.2818702e+13, dtype=float32))
# (33, ' epoch, loss: ', array(2.197694e+13, dtype=float32))
# (34, ' epoch, loss: ', array(2.143974e+13, dtype=float32))
# (35, ' epoch, loss: ', array(2.0851594e+13, dtype=float32))
# (36, ' epoch, loss: ', array(2.0207754e+13, dtype=float32))
# (37, ' epoch, loss: ', array(1.9921273e+13, dtype=float32))
# (38, ' epoch, loss: ', array(1.983368e+13, dtype=float32))
# (39, ' epoch, loss: ', array(1.9563373e+13, dtype=float32))
# (40, ' epoch, loss: ', array(1.9135644e+13, dtype=float32))
# (41, ' epoch, loss: ', array(1.8733146e+13, dtype=float32))
# (42, ' epoch, loss: ', array(1.818242e+13, dtype=float32))
# (43, ' epoch, loss: ', array(1.7436166e+13, dtype=float32))
# (44, ' epoch, loss: ', array(1.6771761e+13, dtype=float32))
# (45, ' epoch, loss: ', array(1.6158447e+13, dtype=float32))
# (46, ' epoch, loss: ', array(1.5500594e+13, dtype=float32))
# (47, ' epoch, loss: ', array(1.4951667e+13, dtype=float32))
# (48, ' epoch, loss: ', array(1.4480763e+13, dtype=float32))
# (49, ' epoch, loss: ', array(1.3837594e+13, dtype=float32))
# (50, ' epoch, loss: ', array(1.3185992e+13, dtype=float32))
# (51, ' epoch, loss: ', array(1.2289488e+13, dtype=float32))
# (52, ' epoch, loss: ', array(1.1200836e+13, dtype=float32))
# (53, ' epoch, loss: ', array(1.015903e+13, dtype=float32))
# (54, ' epoch, loss: ', array(9.301821e+12, dtype=float32))
# (55, ' epoch, loss: ', array(8.6052443e+12, dtype=float32))
# (56, ' epoch, loss: ', array(8.1399146e+12, dtype=float32))
# (57, ' epoch, loss: ', array(8.0747655e+12, dtype=float32))
# (58, ' epoch, loss: ', array(8.6847935e+12, dtype=float32))
# (59, ' epoch, loss: ', array(1.0057514e+13, dtype=float32))
# (60, ' epoch, loss: ', array(8.799186e+12, dtype=float32))
# (61, ' epoch, loss: ', array(8.261705e+12, dtype=float32))
# (62, ' epoch, loss: ', array(6.5943456e+12, dtype=float32))
# (63, ' epoch, loss: ', array(7.3987045e+12, dtype=float32))
# (64, ' epoch, loss: ', array(6.751567e+12, dtype=float32))
# (65, ' epoch, loss: ', array(6.363914e+12, dtype=float32))
# (66, ' epoch, loss: ', array(6.051811e+12, dtype=float32))
# (67, ' epoch, loss: ', array(5.8404467e+12, dtype=float32))
# (68, ' epoch, loss: ', array(5.830342e+12, dtype=float32))
# (69, ' epoch, loss: ', array(5.104913e+12, dtype=float32))
# (70, ' epoch, loss: ', array(5.545082e+12, dtype=float32))
# (71, ' epoch, loss: ', array(4.8323483e+12, dtype=float32))
# (72, ' epoch, loss: ', array(5.139807e+12, dtype=float32))
# (73, ' epoch, loss: ', array(4.3969796e+12, dtype=float32))
# (74, ' epoch, loss: ', array(4.7736936e+12, dtype=float32))
# (75, ' epoch, loss: ', array(4.035099e+12, dtype=float32))
# (76, ' epoch, loss: ', array(4.2661708e+12, dtype=float32))
# (77, ' epoch, loss: ', array(3.7703566e+12, dtype=float32))
# (78, ' epoch, loss: ', array(3.9117568e+12, dtype=float32))
# (79, ' epoch, loss: ', array(3.4751114e+12, dtype=float32))
# (80, ' epoch, loss: ', array(3.583093e+12, dtype=float32))
# (81, ' epoch, loss: ', array(3.2874119e+12, dtype=float32))
# (82, ' epoch, loss: ', array(3.330362e+12, dtype=float32))
# (83, ' epoch, loss: ', array(3.0393796e+12, dtype=float32))
# (84, ' epoch, loss: ', array(3.1117672e+12, dtype=float32))
# (85, ' epoch, loss: ', array(2.8778213e+12, dtype=float32))
# (86, ' epoch, loss: ', array(2.97223e+12, dtype=float32))
# (87, ' epoch, loss: ', array(2.742531e+12, dtype=float32))
# (88, ' epoch, loss: ', array(2.8245846e+12, dtype=float32))
# (89, ' epoch, loss: ', array(2.663142e+12, dtype=float32))
# (90, ' epoch, loss: ', array(2.7222873e+12, dtype=float32))
# (91, ' epoch, loss: ', array(2.642274e+12, dtype=float32))
# (92, ' epoch, loss: ', array(2.6175293e+12, dtype=float32))
# (93, ' epoch, loss: ', array(2.6152387e+12, dtype=float32))
# (94, ' epoch, loss: ', array(2.527967e+12, dtype=float32))
# (95, ' epoch, loss: ', array(2.5726642e+12, dtype=float32))
# (96, ' epoch, loss: ', array(2.4863582e+12, dtype=float32))
# (97, ' epoch, loss: ', array(2.5280756e+12, dtype=float32))
# (98, ' epoch, loss: ', array(2.4731923e+12, dtype=float32))
# (99, ' epoch, loss: ', array(2.4666547e+12, dtype=float32))

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
def plot_surface(data,title=""):
    Xs = data[:,0]
    Ys = data[:,1]
    Zs = data[:,2]
    N = data.shape[0]

    ## plotting surface using X, Y and Z given as 1D data:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    surf = ax.plot_trisurf(Xs, Ys, Zs, cmap=cm.jet, linewidth=0)
    fig.colorbar(surf)

    title = ax.set_title(title)
    title.set_y(1.01)

    ax.xaxis.set_major_locator(MaxNLocator(5))
    ax.yaxis.set_major_locator(MaxNLocator(6))
    ax.zaxis.set_major_locator(MaxNLocator(5))



    fig.tight_layout()
    fig.savefig('3D-reconstructing-{}.png'.format(N))
    plt.show()

# %%
dt=torch.tensor(test)
predictions = []
for i in range(dt.size()[0]):  
    re = np.zeros(m)
    re[0] = dt[i,0]
    re[1] = dt[i,1]
    re = torch.tensor(re) 
    #is this line correct?! I dont think so!
    predictions.append(model(re.float()).item())#+test[i,2])

data_to_plot = dt
predictions = torch.tensor(predictions) 
for i in range(dt.size()[0]):
    data_to_plot[i,2]=predictions[i]

# %%
plot_surface(data_to_plot)

# %%
#np.where((data[:,0]== 1)&(data[:,1]==1))

# %%
re = np.zeros(m)
re[0] = dt[0,0]
re[1] = dt[0,1]
re = torch.tensor(re) 
model(re.float()).item()
# Out:
# 0.5522871017456055

# %%
np.savetxt('gnuformatted_prediction.csv', data_to_plot, delimiter=',')

# %%
test[0,2]
# Out:
# 3.41224e-49

# %%
# gnuplot -c plot gnuformatted_prediction.csv "dudedudedue.png"
