# %% [markdown]
# ## Test on a simple case
# Consider the following Possion Equation
# $$
# \begin{cases}
#     \Delta u = 1\qquad &u\in\Omega\\
#     u = 0\qquad &u\in\partial\Omega.
# \end{cases}$$
# Here $\Omega = \{(x, y)|x^2+y^2 < 1\}$
#
# The exact solution to this problem is $$u = \frac{1}{4}(x^2+y^2-1).$$

# %%
% matplotlib inline
import torch 
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm

torch.set_default_tensor_type('torch.FloatTensor')

class DeepRitzNet(torch.nn.Module):
    def __init__(self, m):
        super(DeepRitzNet, self).__init__()
        self.linear1 = torch.nn.Linear(m,m)
        self.linear2 = torch.nn.Linear(m,m)
        self.linear3 = torch.nn.Linear(m,m)
        self.linear4 = torch.nn.Linear(m,m)
        self.linear5 = torch.nn.Linear(m,m)
        self.linear6 = torch.nn.Linear(m,m)
        
        self.linear7 = torch.nn.Linear(m,1)
      
    def forward(self, x):
        y = x
        y = y + F.relu(self.linear2(F.relu(self.linear1(y))))
        y = y + F.relu(self.linear4(F.relu(self.linear3(y))))
        y = y + F.relu(self.linear6(F.relu(self.linear5(y))))
        output = F.relu(self.linear7(y))
        return output

# %%
def draw_graph(mod, m):
    points = np.arange(-1, 1, 0.01)
    xs, ys = np.meshgrid(points, points)
    xs = torch.tensor(xs)
    ys = torch.tensor(ys)
    xl, yl = xs.size()
    z = np.zeros((xl, yl))
    for i in range(xl):
        for j in range(yl):      
            re = np.zeros(m)
            re[0] = xs[i, j]
            re[1] = ys[i, j]
            re = torch.tensor(re)        
            z[i, j] = mod(re.float()).item() + U_groundtruth(re)
    
    plt.imshow(z, cmap=cm.hot)
    plt.colorbar()
    my_x_ticks = np.arange(-1, 1, 0.2)
    my_y_ticks = np.arange(-1, 1, 0.2)
    ax = plt.gca()
    ax.set_xticks(np.linspace(0,199,9))  
    ax.set_xticklabels(('-1', '-0.75', '-0.5', '-0.25', '0', '0.25', '0.5', '0.75', '1'))  
    ax.set_yticks(np.linspace(0,199,9))  
    ax.set_yticklabels( ('1', '0.75', '0.5', '0.25', '0','-0.25','-0.5','-0.75', '-1'))  
    
    plt.show()

# %%
def cal_loss(mod):
    points = np.arange(-1, 1, 0.1)
    xs, ys = np.meshgrid(points, points)
    xs = torch.tensor(xs)
    ys = torch.tensor(ys)
    xl, yl = xs.size()
    z = np.zeros((xl, yl))
    mmm = 0
    t = 0
    for i in range(xl):
        for j in range(yl):      
            re = np.zeros(m)
            re[0] = xs[i, j]
            re[1] = ys[i, j]
            re = torch.tensor(re)        
            z[i, j] = mod(re.float()).item() + U_groundtruth(re)
          
            if re[0] ** 2 + re[1] ** 2 < 1 : 
                mmm += abs(z[i, j])
                t += 1
    return mmm / t

# %%
def relative_err(mod):
    points = np.arange(-1, 1, 0.1)
    xs, ys = np.meshgrid(points, points)
    xs = torch.tensor(xs)
    ys = torch.tensor(ys)
    xl, yl = xs.size()
    z = np.zeros((xl, yl))
    w = np.zeros((xl, yl))
    t = 0
    for i in range(xl):
        for j in range(yl):      
            re = np.zeros(m)
            re[0] = xs[i, j]
            re[1] = ys[i, j]
            re = torch.tensor(re)
            if re[0] ** 2 + re[1] ** 2 < 1 :
                z[i, j] = mod(re.float()).item() + U_groundtruth(re)
                w[i, j] = U_groundtruth(re)
                t += 1
    z = z ** 2
    w = w ** 2
    return np.sum(z) / np.sum(w)

# %%
def U_groundtruth(t):
    re = (t[0] ** 2 + t[1] ** 2 - 1).item() / 4
    return re

# %%
def validate(mod):
    draw_graph(mod)
    print(cal_loss(mod))

# %%
m = 10
learning_rate = 0.01
iterations = 400  
print_every_iter = 100
beta = 500 #coefficient for the regularization term in the loss expression
n2 = 100  #number of points on the border of Omega
gamma = 10

# %%
"""
Train with the grid
从初始化模型开始训练
"""
model = DeepRitzNet(m)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
in_error_iter = [] 
on_error_iter = [] 
mm = 1
points = np.arange(-1, 1, 0.1)
xs, ys = np.meshgrid(points, points)
xs = torch.tensor(xs)
ys = torch.tensor(ys)
xl, yl = xs.size()
                
for k in range(iterations):
    n1 = 0
    loss = torch.zeros(1)
    for i in range(xl):
        for j in range(yl):        
            x_input = np.zeros(m)
            x_input[0] = xs[i, j]
            x_input[1] = ys[i, j]
            if x_input[0] ** 2 + x_input[1] ** 2 < 1:
                n1 += 1
                x_input = torch.tensor(x_input).float()
                y = model(x_input)
                
                x1 = torch.zeros(m)
                x2 = torch.zeros(m)
                x1[0] = 0.0001
                x2[1] = 0.0001
                x_input_1 = x_input.float() + x1
                x_input_2 = x_input.float() + x2
                x_input_3 = x_input.float() - x1
                x_input_4 = x_input.float() - x2
                x_input_grad_1 = (model(x_input_1) - y) / 0.0001
                x_input_grad_2 = (model(x_input_2) - y) / 0.0001
                #x_input_2_grad_x = (model(x_input_1) + model(x_input_3) - 2 * y) / 0.0001**2
                #x_input_2_grad_y = (model(x_input_2) + model(x_input_4) - 2 * y) / 0.0001**2

                loss += 0.5 * ((x_input_grad_1) ** 2 + (x_input_grad_2) ** 2) - y 
    loss /= n1
    
    regularization = torch.zeros(1)
    for t in range(n2):
        theta = t / n2 * (2 * pi)
        x_input = np.zeros(m)
        x_input[0] = cos(theta)
        x_input[1] = sin(theta)
        x_input = torch.tensor(x_input).float()
        y = model(x_input)
        regularization += y**2 
    regularization *= mm / n2
    if gamma < 500:
        gamma = gamma * 1.01
    if mm < 500:
        mm = mm * 1.01
        
    #print loss
    print(k, " epoch, loss: ", loss.data[0].numpy())
    print(k, " epoch, regularization loss: ", regularization.data[0].numpy())
    print(k, " loss to real solution: ", cal_loss(model))
    if cal_loss(model) < 0.0001:
        break
    
    loss += regularization
    
    optimizer.zero_grad()
    loss.backward()
 
    optimizer.step()
# Out:
# (0, ' epoch, loss: ', array(-0.29168242, dtype=float32))
# (0, ' epoch, regularization loss: ', array(0., dtype=float32))
# (0, ' loss to real solution: ', 0.17055096900923078)
# (1, ' epoch, loss: ', array(-0.36862096, dtype=float32))
# (1, ' epoch, regularization loss: ', array(0.1791603, dtype=float32))
# (1, ' loss to real solution: ', 0.24609436444147598)
# (2, ' epoch, loss: ', array(-0.4216238, dtype=float32))
# (2, ' epoch, regularization loss: ', array(0.20328452, dtype=float32))
# (2, ' loss to real solution: ', 0.2978698494311698)
# (3, ' epoch, loss: ', array(-0.46614802, dtype=float32))
# (3, ' epoch, regularization loss: ', array(0.21573341, dtype=float32))
# (3, ' loss to real solution: ', 0.34259766253627766)
# (4, ' epoch, loss: ', array(-0.50315773, dtype=float32))
# (4, ' epoch, regularization loss: ', array(0.22134157, dtype=float32))
# (4, ' loss to real solution: ', 0.38142558749849)
# (5, ' epoch, loss: ', array(-0.5357357, dtype=float32))
# (5, ' epoch, regularization loss: ', array(0.22428359, dtype=float32))
# (5, ' loss to real solution: ', 0.4176679259289499)
# (6, ' epoch, loss: ', array(-0.563839, dtype=float32))
# (6, ' epoch, regularization loss: ', array(0.2190128, dtype=float32))
# (6, ' loss to real solution: ', 0.45091525371434976)
# (7, ' epoch, loss: ', array(-0.5901125, dtype=float32))
# (7, ' epoch, regularization loss: ', array(0.21140411, dtype=float32))
# (7, ' loss to real solution: ', 0.4845933537544545)
# (8, ' epoch, loss: ', array(-0.61569244, dtype=float32))
# (8, ' epoch, regularization loss: ', array(0.20431429, dtype=float32))
# (8, ' loss to real solution: ', 0.5201278480264535)
# (9, ' epoch, loss: ', array(-0.64323276, dtype=float32))
# (9, ' epoch, regularization loss: ', array(0.19713067, dtype=float32))
# (9, ' loss to real solution: ', 0.5615700142138257)
# (10, ' epoch, loss: ', array(-0.6733901, dtype=float32))
# (10, ' epoch, regularization loss: ', array(0.18906821, dtype=float32))
# (10, ' loss to real solution: ', 0.6103682353143904)
# (11, ' epoch, loss: ', array(-0.70597243, dtype=float32))
# (11, ' epoch, regularization loss: ', array(0.18015514, dtype=float32))
# (11, ' loss to real solution: ', 0.6678751251858529)
# (12, ' epoch, loss: ', array(-0.7383102, dtype=float32))
# (12, ' epoch, regularization loss: ', array(0.1753894, dtype=float32))
# (12, ' loss to real solution: ', 0.7323747057776743)
# (13, ' epoch, loss: ', array(-0.7709631, dtype=float32))
# (13, ' epoch, regularization loss: ', array(0.16782403, dtype=float32))
# (13, ' loss to real solution: ', 0.8056807610919621)
# (14, ' epoch, loss: ', array(-0.81006795, dtype=float32))
# (14, ' epoch, regularization loss: ', array(0.16986239, dtype=float32))
# (14, ' loss to real solution: ', 0.8889079158099134)
# (15, ' epoch, loss: ', array(-0.8568757, dtype=float32))
# (15, ' epoch, regularization loss: ', array(0.18954116, dtype=float32))
# (15, ' loss to real solution: ', 0.9864535696790149)
# (16, ' epoch, loss: ', array(-0.90551317, dtype=float32))
# (16, ' epoch, regularization loss: ', array(0.2173805, dtype=float32))
# (16, ' loss to real solution: ', 1.0871573465200093)
# (17, ' epoch, loss: ', array(-0.94385177, dtype=float32))
# (17, ' epoch, regularization loss: ', array(0.22856492, dtype=float32))
# (17, ' loss to real solution: ', 1.1805673792584528)
# (18, ' epoch, loss: ', array(-0.98732674, dtype=float32))
# (18, ' epoch, regularization loss: ', array(0.2529557, dtype=float32))
# (18, ' loss to real solution: ', 1.2792426563305868)
# (19, ' epoch, loss: ', array(-1.0118145, dtype=float32))
# (19, ' epoch, regularization loss: ', array(0.25307572, dtype=float32))
# (19, ' loss to real solution: ', 1.3613399210620154)
# (20, ' epoch, loss: ', array(-1.0305799, dtype=float32))
# (20, ' epoch, regularization loss: ', array(0.24691014, dtype=float32))
# (20, ' loss to real solution: ', 1.4358511527788216)
# (21, ' epoch, loss: ', array(-1.0330863, dtype=float32))
# (21, ' epoch, regularization loss: ', array(0.22541322, dtype=float32))
# (21, ' loss to real solution: ', 1.4908471491712465)
# (22, ' epoch, loss: ', array(-1.0200024, dtype=float32))
# (22, ' epoch, regularization loss: ', array(0.1867972, dtype=float32))
# (22, ' loss to real solution: ', 1.5275205301855155)
# (23, ' epoch, loss: ', array(-0.99187505, dtype=float32))
# (23, ' epoch, regularization loss: ', array(0.15051085, dtype=float32))
# (23, ' loss to real solution: ', 1.551082354071056)
# (24, ' epoch, loss: ', array(-0.9753426, dtype=float32))
# (24, ' epoch, regularization loss: ', array(0.12957303, dtype=float32))
# (24, ' loss to real solution: ', 1.573341467081542)
# (25, ' epoch, loss: ', array(-0.9816008, dtype=float32))
# (25, ' epoch, regularization loss: ', array(0.12253993, dtype=float32))
# (25, ' loss to real solution: ', 1.600561481767912)
# (26, ' epoch, loss: ', array(-0.99942416, dtype=float32))
# (26, ' epoch, regularization loss: ', array(0.13169563, dtype=float32))
# (26, ' loss to real solution: ', 1.6285779449295767)
# (27, ' epoch, loss: ', array(-1.0420191, dtype=float32))
# (27, ' epoch, regularization loss: ', array(0.1669536, dtype=float32))
# (27, ' loss to real solution: ', 1.6644457901559075)
# (28, ' epoch, loss: ', array(-1.0749782, dtype=float32))
# (28, ' epoch, regularization loss: ', array(0.19715956, dtype=float32))
# (28, ' loss to real solution: ', 1.6888657429747258)
# (29, ' epoch, loss: ', array(-1.1015251, dtype=float32))
# (29, ' epoch, regularization loss: ', array(0.21609126, dtype=float32))
# (29, ' loss to real solution: ', 1.702216813318982)
# (30, ' epoch, loss: ', array(-1.1508728, dtype=float32))
# (30, ' epoch, regularization loss: ', array(0.28201026, dtype=float32))
# (30, ' loss to real solution: ', 1.7326793832564273)
# (31, ' epoch, loss: ', array(-1.1751323, dtype=float32))
# (31, ' epoch, regularization loss: ', array(0.31279138, dtype=float32))
# (31, ' loss to real solution: ', 1.7375838640571781)
# (32, ' epoch, loss: ', array(-1.1661029, dtype=float32))
# (32, ' epoch, regularization loss: ', array(0.29957265, dtype=float32))
# (32, ' loss to real solution: ', 1.7157537526026412)
# (33, ' epoch, loss: ', array(-1.1284571, dtype=float32))
# (33, ' epoch, regularization loss: ', array(0.2509802, dtype=float32))
# (33, ' loss to real solution: ', 1.675272569296061)
# (34, ' epoch, loss: ', array(-1.0783749, dtype=float32))
# (34, ' epoch, regularization loss: ', array(0.18908204, dtype=float32))
# (34, ' loss to real solution: ', 1.6283251785925343)
# (35, ' epoch, loss: ', array(-1.0276517, dtype=float32))
# (35, ' epoch, regularization loss: ', array(0.13966866, dtype=float32))
# (35, ' loss to real solution: ', 1.5875526525736618)
# (36, ' epoch, loss: ', array(-0.9933148, dtype=float32))
# (36, ' epoch, regularization loss: ', array(0.10760894, dtype=float32))
# (36, ' loss to real solution: ', 1.5676352065437476)
# (37, ' epoch, loss: ', array(-1.0058724, dtype=float32))
# (37, ' epoch, regularization loss: ', array(0.10135955, dtype=float32))
# (37, ' loss to real solution: ', 1.5815053648274044)
# (38, ' epoch, loss: ', array(-1.0291806, dtype=float32))
# (38, ' epoch, regularization loss: ', array(0.10432875, dtype=float32))
# (38, ' loss to real solution: ', 1.6155698321409928)
# (39, ' epoch, loss: ', array(-1.0582777, dtype=float32))
# (39, ' epoch, regularization loss: ', array(0.12318892, dtype=float32))
# (39, ' loss to real solution: ', 1.6640185606402977)
# (40, ' epoch, loss: ', array(-1.0888081, dtype=float32))
# (40, ' epoch, regularization loss: ', array(0.14372279, dtype=float32))
# (40, ' loss to real solution: ', 1.719087602524895)
# (41, ' epoch, loss: ', array(-1.1141561, dtype=float32))
# (41, ' epoch, regularization loss: ', array(0.15816104, dtype=float32))
# (41, ' loss to real solution: ', 1.7729203264966265)
# (42, ' epoch, loss: ', array(-1.1276114, dtype=float32))
# (42, ' epoch, regularization loss: ', array(0.16874786, dtype=float32))
# (42, ' loss to real solution: ', 1.8186629219990442)
# (43, ' epoch, loss: ', array(-1.2207786, dtype=float32))
# (43, ' epoch, regularization loss: ', array(0.30274558, dtype=float32))
# (43, ' loss to real solution: ', 1.906603724910514)
# (44, ' epoch, loss: ', array(-1.2826635, dtype=float32))
# (44, ' epoch, regularization loss: ', array(0.39752355, dtype=float32))
# (44, ' loss to real solution: ', 1.9490171117951238)
# (45, ' epoch, loss: ', array(-1.2820376, dtype=float32))
# (45, ' epoch, regularization loss: ', array(0.40256608, dtype=float32))
# (45, ' loss to real solution: ', 1.9364079941277323)
# (46, ' epoch, loss: ', array(-1.2456374, dtype=float32))
# (46, ' epoch, regularization loss: ', array(0.3325381, dtype=float32))
# (46, ' loss to real solution: ', 1.8790879769877211)
# (47, ' epoch, loss: ', array(-1.1813478, dtype=float32))
# (47, ' epoch, regularization loss: ', array(0.2549832, dtype=float32))
# (47, ' loss to real solution: ', 1.8006193380033844)
# (48, ' epoch, loss: ', array(-1.1152852, dtype=float32))
# (48, ' epoch, regularization loss: ', array(0.17873995, dtype=float32))
# (48, ' loss to real solution: ', 1.7164430592374398)
# (49, ' epoch, loss: ', array(-1.0149527, dtype=float32))
# (49, ' epoch, regularization loss: ', array(0.1054661, dtype=float32))
# (49, ' loss to real solution: ', 1.6163455158721212)
# (50, ' epoch, loss: ', array(-0.9368763, dtype=float32))
# (50, ' epoch, regularization loss: ', array(0.06610832, dtype=float32))
# (50, ' loss to real solution: ', 1.5397809809005527)
# (51, ' epoch, loss: ', array(-0.88548344, dtype=float32))
# (51, ' epoch, regularization loss: ', array(0.04337791, dtype=float32))
# (51, ' loss to real solution: ', 1.4888418597577084)
# (52, ' epoch, loss: ', array(-0.8507874, dtype=float32))
# (52, ' epoch, regularization loss: ', array(0.03197482, dtype=float32))
# (52, ' loss to real solution: ', 1.4629741377635017)
# (53, ' epoch, loss: ', array(-0.8322968, dtype=float32))
# (53, ' epoch, regularization loss: ', array(0.02882155, dtype=float32))
# (53, ' loss to real solution: ', 1.4580575645506573)
# (54, ' epoch, loss: ', array(-0.8311747, dtype=float32))
# (54, ' epoch, regularization loss: ', array(0.03238083, dtype=float32))
# (54, ' loss to real solution: ', 1.4706462698791571)
# (55, ' epoch, loss: ', array(-0.8484348, dtype=float32))
# (55, ' epoch, regularization loss: ', array(0.04188714, dtype=float32))
# (55, ' loss to real solution: ', 1.4956154967005995)
# (56, ' epoch, loss: ', array(-0.8750249, dtype=float32))
# (56, ' epoch, regularization loss: ', array(0.05767914, dtype=float32))
# (56, ' loss to real solution: ', 1.528301050613164)
# (57, ' epoch, loss: ', array(-0.90644157, dtype=float32))
# (57, ' epoch, regularization loss: ', array(0.07952069, dtype=float32))
# (57, ' loss to real solution: ', 1.5638881144569616)
# (58, ' epoch, loss: ', array(-0.9411729, dtype=float32))
# (58, ' epoch, regularization loss: ', array(0.1058504, dtype=float32))
# (58, ' loss to real solution: ', 1.5971774005583244)
# (59, ' epoch, loss: ', array(-0.9831913, dtype=float32))
# (59, ' epoch, regularization loss: ', array(0.13381125, dtype=float32))
# (59, ' loss to real solution: ', 1.6236913902736552)
# (60, ' epoch, loss: ', array(-1.0204296, dtype=float32))
# (60, ' epoch, regularization loss: ', array(0.15844509, dtype=float32))
# (60, ' loss to real solution: ', 1.6407552513815582)
# (61, ' epoch, loss: ', array(-1.0423136, dtype=float32))
# (61, ' epoch, regularization loss: ', array(0.18218324, dtype=float32))
# (61, ' loss to real solution: ', 1.647238038739974)
# (62, ' epoch, loss: ', array(-1.0593486, dtype=float32))
# (62, ' epoch, regularization loss: ', array(0.190092, dtype=float32))
# (62, ' loss to real solution: ', 1.6413054002404595)
# (63, ' epoch, loss: ', array(-1.0584037, dtype=float32))
# (63, ' epoch, regularization loss: ', array(0.18229364, dtype=float32))
# (63, ' loss to real solution: ', 1.6256010553422848)
# (64, ' epoch, loss: ', array(-1.0428941, dtype=float32))
# (64, ' epoch, regularization loss: ', array(0.16775021, dtype=float32))
# (64, ' loss to real solution: ', 1.6033358100487871)
# (65, ' epoch, loss: ', array(-1.0324438, dtype=float32))
# (65, ' epoch, regularization loss: ', array(0.14985387, dtype=float32))
# (65, ' loss to real solution: ', 1.5778714580321234)
# (66, ' epoch, loss: ', array(-0.99049765, dtype=float32))
# (66, ' epoch, regularization loss: ', array(0.110709, dtype=float32))
# (66, ' loss to real solution: ', 1.530333595640023)
# (67, ' epoch, loss: ', array(-0.94397867, dtype=float32))
# (67, ' epoch, regularization loss: ', array(0.08386583, dtype=float32))
# (67, ' loss to real solution: ', 1.4762413443246454)
# (68, ' epoch, loss: ', array(-0.9025182, dtype=float32))
# (68, ' epoch, regularization loss: ', array(0.06924458, dtype=float32))
# (68, ' loss to real solution: ', 1.4369800904326118)
# (69, ' epoch, loss: ', array(-0.91027254, dtype=float32))
# (69, ' epoch, regularization loss: ', array(0.08524742, dtype=float32))
# (69, ' loss to real solution: ', 1.4312176595125168)
# (70, ' epoch, loss: ', array(-0.9309729, dtype=float32))
# (70, ' epoch, regularization loss: ', array(0.10668659, dtype=float32))
# (70, ' loss to real solution: ', 1.4338982639933704)
# (71, ' epoch, loss: ', array(-0.96186763, dtype=float32))
# (71, ' epoch, regularization loss: ', array(0.12967306, dtype=float32))
# (71, ' loss to real solution: ', 1.4414842056844779)
# (72, ' epoch, loss: ', array(-0.99807876, dtype=float32))
# (72, ' epoch, regularization loss: ', array(0.15034692, dtype=float32))
# (72, ' loss to real solution: ', 1.4515924561981985)
# (73, ' epoch, loss: ', array(-1.0673348, dtype=float32))
# (73, ' epoch, regularization loss: ', array(0.21843605, dtype=float32))
# (73, ' loss to real solution: ', 1.4951302760820298)
# (74, ' epoch, loss: ', array(-1.1191468, dtype=float32))
# (74, ' epoch, regularization loss: ', array(0.28868037, dtype=float32))
# (74, ' loss to real solution: ', 1.5274780631218692)
# (75, ' epoch, loss: ', array(-1.138746, dtype=float32))
# (75, ' epoch, regularization loss: ', array(0.32006997, dtype=float32))
# (75, ' loss to real solution: ', 1.5420521573391757)
# (76, ' epoch, loss: ', array(-1.1345627, dtype=float32))
# (76, ' epoch, regularization loss: ', array(0.33409607, dtype=float32))
# (76, ' loss to real solution: ', 1.5370098065869984)
# (77, ' epoch, loss: ', array(-1.1083289, dtype=float32))
# (77, ' epoch, regularization loss: ', array(0.31440738, dtype=float32))
# (77, ' loss to real solution: ', 1.5118284128639858)
# (78, ' epoch, loss: ', array(-1.0676693, dtype=float32))
# (78, ' epoch, regularization loss: ', array(0.2610757, dtype=float32))
# (78, ' loss to real solution: ', 1.4694762731058422)
# (79, ' epoch, loss: ', array(-1.0126656, dtype=float32))
# (79, ' epoch, regularization loss: ', array(0.18944725, dtype=float32))
# (79, ' loss to real solution: ', 1.4174867172678185)
# (80, ' epoch, loss: ', array(-0.95459974, dtype=float32))
# (80, ' epoch, regularization loss: ', array(0.10966575, dtype=float32))
# (80, ' loss to real solution: ', 1.3542453316975251)
# (81, ' epoch, loss: ', array(-0.8673228, dtype=float32))
# (81, ' epoch, regularization loss: ', array(0.0487922, dtype=float32))
# (81, ' loss to real solution: ', 1.304864146506288)
# (82, ' epoch, loss: ', array(-0.8160615, dtype=float32))
# (82, ' epoch, regularization loss: ', array(0.01626534, dtype=float32))
# (82, ' loss to real solution: ', 1.2764749456985203)
# (83, ' epoch, loss: ', array(-0.79564947, dtype=float32))
# (83, ' epoch, regularization loss: ', array(0.00386458, dtype=float32))
# (83, ' loss to real solution: ', 1.2728868623695955)
# (84, ' epoch, loss: ', array(-0.777134, dtype=float32))
# (84, ' epoch, regularization loss: ', array(0.00139142, dtype=float32))
# (84, ' loss to real solution: ', 1.2987813174782075)
# (85, ' epoch, loss: ', array(-0.7827233, dtype=float32))
# (85, ' epoch, regularization loss: ', array(0.00247913, dtype=float32))
# (85, ' loss to real solution: ', 1.3502343829287593)
# (86, ' epoch, loss: ', array(-0.8038386, dtype=float32))
# (86, ' epoch, regularization loss: ', array(0.00868374, dtype=float32))
# (86, ' loss to real solution: ', 1.421801561228332)
# (87, ' epoch, loss: ', array(-0.84447044, dtype=float32))
# (87, ' epoch, regularization loss: ', array(0.02548701, dtype=float32))
# (87, ' loss to real solution: ', 1.5055864825566865)
# (88, ' epoch, loss: ', array(-0.8934956, dtype=float32))
# (88, ' epoch, regularization loss: ', array(0.0605152, dtype=float32))
# (88, ' loss to real solution: ', 1.5940442855680104)
# (89, ' epoch, loss: ', array(-0.9648823, dtype=float32))
# (89, ' epoch, regularization loss: ', array(0.10730971, dtype=float32))
# (89, ' loss to real solution: ', 1.6707778938100268)
# (90, ' epoch, loss: ', array(-1.0143417, dtype=float32))
# (90, ' epoch, regularization loss: ', array(0.14774323, dtype=float32))
# (90, ' loss to real solution: ', 1.7234718937544193)
# (91, ' epoch, loss: ', array(-1.0262425, dtype=float32))
# (91, ' epoch, regularization loss: ', array(0.16117732, dtype=float32))
# (91, ' loss to real solution: ', 1.7458025059860998)
# (92, ' epoch, loss: ', array(-1.0351933, dtype=float32))
# (92, ' epoch, regularization loss: ', array(0.14201707, dtype=float32))
# (92, ' loss to real solution: ', 1.7360921124515043)
# (93, ' epoch, loss: ', array(-1.0274839, dtype=float32))
# (93, ' epoch, regularization loss: ', array(0.10830415, dtype=float32))
# (93, ' loss to real solution: ', 1.7060215590046148)
# (94, ' epoch, loss: ', array(-0.9951428, dtype=float32))
# (94, ' epoch, regularization loss: ', array(0.07455225, dtype=float32))
# (94, ' loss to real solution: ', 1.6613502590564286)
# (95, ' epoch, loss: ', array(-0.96307635, dtype=float32))
# (95, ' epoch, regularization loss: ', array(0.04323855, dtype=float32))
# (95, ' loss to real solution: ', 1.6180594014354839)
# (96, ' epoch, loss: ', array(-0.9288843, dtype=float32))
# (96, ' epoch, regularization loss: ', array(0.02367377, dtype=float32))
# (96, ' loss to real solution: ', 1.5869792197639918)
# (97, ' epoch, loss: ', array(-0.9185839, dtype=float32))
# (97, ' epoch, regularization loss: ', array(0.01592305, dtype=float32))
# (97, ' loss to real solution: ', 1.5753138203291261)
# (98, ' epoch, loss: ', array(-0.9285177, dtype=float32))
# (98, ' epoch, regularization loss: ', array(0.01791184, dtype=float32))
# (98, ' loss to real solution: ', 1.5860899142475373)
# (99, ' epoch, loss: ', array(-0.9407244, dtype=float32))
# (99, ' epoch, regularization loss: ', array(0.03128985, dtype=float32))
# (99, ' loss to real solution: ', 1.6169546602968234)
# (100, ' epoch, loss: ', array(-0.9762336, dtype=float32))
# (100, ' epoch, regularization loss: ', array(0.05653316, dtype=float32))
# (100, ' loss to real solution: ', 1.6583535696110925)
# (101, ' epoch, loss: ', array(-0.9999813, dtype=float32))
# (101, ' epoch, regularization loss: ', array(0.08803936, dtype=float32))
# (101, ' loss to real solution: ', 1.6990115235242813)
# (102, ' epoch, loss: ', array(-1.0200671, dtype=float32))
# (102, ' epoch, regularization loss: ', array(0.10954746, dtype=float32))
# (102, ' loss to real solution: ', 1.7272805154668551)
# (103, ' epoch, loss: ', array(-1.012449, dtype=float32))
# (103, ' epoch, regularization loss: ', array(0.1074982, dtype=float32))
# (103, ' loss to real solution: ', 1.7376546522390417)
# (104, ' epoch, loss: ', array(-0.9780776, dtype=float32))
# (104, ' epoch, regularization loss: ', array(0.08561219, dtype=float32))
# (104, ' loss to real solution: ', 1.730510752967699)
# (105, ' epoch, loss: ', array(-0.956421, dtype=float32))
# (105, ' epoch, regularization loss: ', array(0.06164046, dtype=float32))
# (105, ' loss to real solution: ', 1.7199934860862716)
# (106, ' epoch, loss: ', array(-0.9079013, dtype=float32))
# (106, ' epoch, regularization loss: ', array(0.04476517, dtype=float32))
# (106, ' loss to real solution: ', 1.7095309570632942)
# (107, ' epoch, loss: ', array(-1.1163931, dtype=float32))
# (107, ' epoch, regularization loss: ', array(0.26724038, dtype=float32))
# (107, ' loss to real solution: ', 1.7980845777513121)
# (108, ' epoch, loss: ', array(-1.2275102, dtype=float32))
# (108, ' epoch, regularization loss: ', array(0.46235743, dtype=float32))
# (108, ' loss to real solution: ', 1.8199907850759198)
# (109, ' epoch, loss: ', array(-1.2277491, dtype=float32))
# (109, ' epoch, regularization loss: ', array(0.45834196, dtype=float32))
# (109, ' loss to real solution: ', 1.7674508262447215)
# (110, ' epoch, loss: ', array(-1.1500357, dtype=float32))
# (110, ' epoch, regularization loss: ', array(0.28705573, dtype=float32))
# (110, ' loss to real solution: ', 1.662780234185062)
# (111, ' epoch, loss: ', array(-1.0353041, dtype=float32))
# (111, ' epoch, regularization loss: ', array(0.10329953, dtype=float32))
# (111, ' loss to real solution: ', 1.5376075026076705)
# (112, ' epoch, loss: ', array(-0.9283195, dtype=float32))
# (112, ' epoch, regularization loss: ', array(0.01170275, dtype=float32))
# (112, ' loss to real solution: ', 1.4272251399345335)
# (113, ' epoch, loss: ', array(-0.84461784, dtype=float32))
# (113, ' epoch, regularization loss: ', array(0., dtype=float32))
# (113, ' loss to real solution: ', 1.3611279871647763)
# (114, ' epoch, loss: ', array(-0.8140033, dtype=float32))
# (114, ' epoch, regularization loss: ', array(0., dtype=float32))
# (114, ' loss to real solution: ', 1.3441191423897576)
# (115, ' epoch, loss: ', array(-0.8102067, dtype=float32))
# (115, ' epoch, regularization loss: ', array(0., dtype=float32))
# (115, ' loss to real solution: ', 1.3666468782976893)
# (116, ' epoch, loss: ', array(-0.8637414, dtype=float32))
# (116, ' epoch, regularization loss: ', array(1.00870174e-07, dtype=float32))
# (116, ' loss to real solution: ', 1.4222953136960026)
# (117, ' epoch, loss: ', array(-0.9379907, dtype=float32))
# (117, ' epoch, regularization loss: ', array(0.02064539, dtype=float32))
# (117, ' loss to real solution: ', 1.508125123291537)
# (118, ' epoch, loss: ', array(-1.0229685, dtype=float32))
# (118, ' epoch, regularization loss: ', array(0.08949423, dtype=float32))
# (118, ' loss to real solution: ', 1.605448130047206)
# (119, ' epoch, loss: ', array(-1.0871842, dtype=float32))
# (119, ' epoch, regularization loss: ', array(0.16923033, dtype=float32))
# (119, ' loss to real solution: ', 1.6920335495931924)
# (120, ' epoch, loss: ', array(-1.1138575, dtype=float32))
# (120, ' epoch, regularization loss: ', array(0.19136882, dtype=float32))
# (120, ' loss to real solution: ', 1.749912228515293)
# (121, ' epoch, loss: ', array(-1.1018298, dtype=float32))
# (121, ' epoch, regularization loss: ', array(0.13919911, dtype=float32))
# (121, ' loss to real solution: ', 1.7746367999748394)
# (122, ' epoch, loss: ', array(-1.0514807, dtype=float32))
# (122, ' epoch, regularization loss: ', array(0.08557387, dtype=float32))
# (122, ' loss to real solution: ', 1.77776418793623)
# (123, ' epoch, loss: ', array(-0.9959431, dtype=float32))
# (123, ' epoch, regularization loss: ', array(0.04411665, dtype=float32))
# (123, ' loss to real solution: ', 1.771529706053411)
# (124, ' epoch, loss: ', array(-0.9315901, dtype=float32))
# (124, ' epoch, regularization loss: ', array(0.01957317, dtype=float32))
# (124, ' loss to real solution: ', 1.7675987285586408)
# (125, ' epoch, loss: ', array(-0.91094595, dtype=float32))
# (125, ' epoch, regularization loss: ', array(0.0106239, dtype=float32))
# (125, ' loss to real solution: ', 1.7724980703274145)
# (126, ' epoch, loss: ', array(-0.91343653, dtype=float32))
# (126, ' epoch, regularization loss: ', array(0.01222186, dtype=float32))
# (126, ' loss to real solution: ', 1.7895987564689468)
# (127, ' epoch, loss: ', array(-0.93834037, dtype=float32))
# (127, ' epoch, regularization loss: ', array(0.02472575, dtype=float32))
# (127, ' loss to real solution: ', 1.8159282708627993)
# (128, ' epoch, loss: ', array(-0.95857203, dtype=float32))
# (128, ' epoch, regularization loss: ', array(0.0501624, dtype=float32))
# (128, ' loss to real solution: ', 1.8435833024786974)
# (129, ' epoch, loss: ', array(-0.9965145, dtype=float32))
# (129, ' epoch, regularization loss: ', array(0.08066291, dtype=float32))
# (129, ' loss to real solution: ', 1.8610788104580138)
# (130, ' epoch, loss: ', array(-1.0275271, dtype=float32))
# (130, ' epoch, regularization loss: ', array(0.10221656, dtype=float32))
# (130, ' loss to real solution: ', 1.8596431427024944)
# (131, ' epoch, loss: ', array(-1.0316887, dtype=float32))
# (131, ' epoch, regularization loss: ', array(0.09752735, dtype=float32))
# (131, ' loss to real solution: ', 1.836202931649431)
# (132, ' epoch, loss: ', array(-0.9996734, dtype=float32))
# (132, ' epoch, regularization loss: ', array(0.06873181, dtype=float32))
# (132, ' loss to real solution: ', 1.7955223282587098)
# (133, ' epoch, loss: ', array(-0.9822207, dtype=float32))
# (133, ' epoch, regularization loss: ', array(0.04069496, dtype=float32))
# (133, ' loss to real solution: ', 1.748278475934669)
# (134, ' epoch, loss: ', array(-0.9666332, dtype=float32))
# (134, ' epoch, regularization loss: ', array(0.02525308, dtype=float32))
# (134, ' loss to real solution: ', 1.70708695494477)
# (135, ' epoch, loss: ', array(-0.9620357, dtype=float32))
# (135, ' epoch, regularization loss: ', array(0.02072662, dtype=float32))
# (135, ' loss to real solution: ', 1.6781469351570706)
# (136, ' epoch, loss: ', array(-0.98478144, dtype=float32))
# (136, ' epoch, regularization loss: ', array(0.02591628, dtype=float32))
# (136, ' loss to real solution: ', 1.6633178200714074)
# (137, ' epoch, loss: ', array(-1.0140753, dtype=float32))
# (137, ' epoch, regularization loss: ', array(0.04399391, dtype=float32))
# (137, ' loss to real solution: ', 1.6601606478031807)
# (138, ' epoch, loss: ', array(-1.0378041, dtype=float32))
# (138, ' epoch, regularization loss: ', array(0.0682447, dtype=float32))
# (138, ' loss to real solution: ', 1.6607734294527978)
# (139, ' epoch, loss: ', array(-1.0493684, dtype=float32))
# (139, ' epoch, regularization loss: ', array(0.08181491, dtype=float32))
# (139, ' loss to real solution: ', 1.657801106520404)
# (140, ' epoch, loss: ', array(-1.0614793, dtype=float32))
# (140, ' epoch, regularization loss: ', array(0.08204019, dtype=float32))
# (140, ' loss to real solution: ', 1.6538413112339863)
# (141, ' epoch, loss: ', array(-1.0387915, dtype=float32))
# (141, ' epoch, regularization loss: ', array(0.06029228, dtype=float32))
# (141, ' loss to real solution: ', 1.6434158270727015)
# (142, ' epoch, loss: ', array(-1.0228233, dtype=float32))
# (142, ' epoch, regularization loss: ', array(0.04617769, dtype=float32))
# (142, ' loss to real solution: ', 1.6329944901297713)
# (143, ' epoch, loss: ', array(-1.0067332, dtype=float32))
# (143, ' epoch, regularization loss: ', array(0.03347252, dtype=float32))
# (143, ' loss to real solution: ', 1.6276241016694586)
# (144, ' epoch, loss: ', array(-0.9965782, dtype=float32))
# (144, ' epoch, regularization loss: ', array(0.02611901, dtype=float32))
# (144, ' loss to real solution: ', 1.630977359132368)
# (145, ' epoch, loss: ', array(-0.99712175, dtype=float32))
# (145, ' epoch, regularization loss: ', array(0.02648793, dtype=float32))
# (145, ' loss to real solution: ', 1.6446379902240162)
# (146, ' epoch, loss: ', array(-1.0191505, dtype=float32))
# (146, ' epoch, regularization loss: ', array(0.03481877, dtype=float32))
# (146, ' loss to real solution: ', 1.6670861590100254)
# (147, ' epoch, loss: ', array(-1.0316329, dtype=float32))
# (147, ' epoch, regularization loss: ', array(0.0481906, dtype=float32))
# (147, ' loss to real solution: ', 1.6913647904618379)
# (148, ' epoch, loss: ', array(-1.0368154, dtype=float32))
# (148, ' epoch, regularization loss: ', array(0.05852343, dtype=float32))
# (148, ' loss to real solution: ', 1.7125331371313501)
# (149, ' epoch, loss: ', array(-1.0273714, dtype=float32))
# (149, ' epoch, regularization loss: ', array(0.05344616, dtype=float32))
# (149, ' loss to real solution: ', 1.7262812858570806)
# (150, ' epoch, loss: ', array(-1.0201032, dtype=float32))
# (150, ' epoch, regularization loss: ', array(0.03872367, dtype=float32))
# (150, ' loss to real solution: ', 1.7337627369644553)
# (151, ' epoch, loss: ', array(-1.0016814, dtype=float32))
# (151, ' epoch, regularization loss: ', array(0.02840993, dtype=float32))
# (151, ' loss to real solution: ', 1.7406198972636093)
# (152, ' epoch, loss: ', array(-1.0222429, dtype=float32))
# (152, ' epoch, regularization loss: ', array(0.03803029, dtype=float32))
# (152, ' loss to real solution: ', 1.7532329205684718)
# (153, ' epoch, loss: ', array(-1.0331017, dtype=float32))
# (153, ' epoch, regularization loss: ', array(0.05690959, dtype=float32))
# (153, ' loss to real solution: ', 1.7665121771859962)
# (154, ' epoch, loss: ', array(-1.0485387, dtype=float32))
# (154, ' epoch, regularization loss: ', array(0.0686394, dtype=float32))
# (154, ' loss to real solution: ', 1.773165220995807)
# (155, ' epoch, loss: ', array(-1.0231135, dtype=float32))
# (155, ' epoch, regularization loss: ', array(0.06074489, dtype=float32))
# (155, ' loss to real solution: ', 1.7694534326826252)
# (156, ' epoch, loss: ', array(-1.0181532, dtype=float32))
# (156, ' epoch, regularization loss: ', array(0.04373894, dtype=float32))
# (156, ' loss to real solution: ', 1.7578570931824067)
# (157, ' epoch, loss: ', array(-1.045387, dtype=float32))
# (157, ' epoch, regularization loss: ', array(0.06039855, dtype=float32))
# (157, ' loss to real solution: ', 1.7598882583904871)
# (158, ' epoch, loss: ', array(-1.0548006, dtype=float32))
# (158, ' epoch, regularization loss: ', array(0.06328743, dtype=float32))
# (158, ' loss to real solution: ', 1.754722396273321)
# (159, ' epoch, loss: ', array(-1.0583571, dtype=float32))
# (159, ' epoch, regularization loss: ', array(0.05343933, dtype=float32))
# (159, ' loss to real solution: ', 1.7428105252118735)
# (160, ' epoch, loss: ', array(-1.0988969, dtype=float32))
# (160, ' epoch, regularization loss: ', array(0.10884741, dtype=float32))
# (160, ' loss to real solution: ', 1.742199677263425)
# (161, ' epoch, loss: ', array(-1.0857371, dtype=float32))
# (161, ' epoch, regularization loss: ', array(0.08462177, dtype=float32))
# (161, ' loss to real solution: ', 1.7140398345537886)
# (162, ' epoch, loss: ', array(-1.0290602, dtype=float32))
# (162, ' epoch, regularization loss: ', array(0.02171432, dtype=float32))
# (162, ' loss to real solution: ', 1.669904389274082)
# (163, ' epoch, loss: ', array(-0.9799745, dtype=float32))
# (163, ' epoch, regularization loss: ', array(0.00379215, dtype=float32))
# (163, ' loss to real solution: ', 1.6428415347870522)
# (164, ' epoch, loss: ', array(-0.99771047, dtype=float32))
# (164, ' epoch, regularization loss: ', array(0.00999919, dtype=float32))
# (164, ' loss to real solution: ', 1.6488306019237187)
# (165, ' epoch, loss: ', array(-1.0499223, dtype=float32))
# (165, ' epoch, regularization loss: ', array(0.04491873, dtype=float32))
# (165, ' loss to real solution: ', 1.6764653643189518)
# (166, ' epoch, loss: ', array(-1.0960362, dtype=float32))
# (166, ' epoch, regularization loss: ', array(0.10813521, dtype=float32))
# (166, ' loss to real solution: ', 1.7057241137158066)
# (167, ' epoch, loss: ', array(-1.0790948, dtype=float32))
# (167, ' epoch, regularization loss: ', array(0.07571556, dtype=float32))
# (167, ' loss to real solution: ', 1.7026828119187492)
# (168, ' epoch, loss: ', array(-1.0182188, dtype=float32))
# (168, ' epoch, regularization loss: ', array(0.02616413, dtype=float32))
# (168, ' loss to real solution: ', 1.68320248891303)
# (169, ' epoch, loss: ', array(-0.9738018, dtype=float32))
# (169, ' epoch, regularization loss: ', array(0.0065829, dtype=float32))
# (169, ' loss to real solution: ', 1.6742882986314043)
# (170, ' epoch, loss: ', array(-0.98893046, dtype=float32))
# (170, ' epoch, regularization loss: ', array(0.01218451, dtype=float32))
# (170, ' loss to real solution: ', 1.6920588525315188)
# (171, ' epoch, loss: ', array(-1.036255, dtype=float32))
# (171, ' epoch, regularization loss: ', array(0.04280214, dtype=float32))
# (171, ' loss to real solution: ', 1.7273470395209316)
# (172, ' epoch, loss: ', array(-1.0614622, dtype=float32))
# (172, ' epoch, regularization loss: ', array(0.08413386, dtype=float32))
# (172, ' loss to real solution: ', 1.7574466974750584)
# (173, ' epoch, loss: ', array(-1.0620553, dtype=float32))
# (173, ' epoch, regularization loss: ', array(0.09872263, dtype=float32))
# (173, ' loss to real solution: ', 1.7651226940224016)
# (174, ' epoch, loss: ', array(-1.0038899, dtype=float32))
# (174, ' epoch, regularization loss: ', array(0.03822401, dtype=float32))
# (174, ' loss to real solution: ', 1.7374399519963275)
# (175, ' epoch, loss: ', array(-0.9126388, dtype=float32))
# (175, ' epoch, regularization loss: ', array(0.0026921, dtype=float32))
# (175, ' loss to real solution: ', 1.6983406641437309)
# (176, ' epoch, loss: ', array(-0.88535017, dtype=float32))
# (176, ' epoch, regularization loss: ', array(0.00830197, dtype=float32))
# (176, ' loss to real solution: ', 1.6909948633376428)
# (177, ' epoch, loss: ', array(-0.8885671, dtype=float32))
# (177, ' epoch, regularization loss: ', array(0.03564234, dtype=float32))
# (177, ' loss to real solution: ', 1.6929380013015112)
# (178, ' epoch, loss: ', array(-0.91747487, dtype=float32))
# (178, ' epoch, regularization loss: ', array(0.07604559, dtype=float32))
# (178, ' loss to real solution: ', 1.690452483493799)
# (179, ' epoch, loss: ', array(-0.7594619, dtype=float32))
# (179, ' epoch, regularization loss: ', array(0.00378519, dtype=float32))
# (179, ' loss to real solution: ', 1.5640611447283692)
# (180, ' epoch, loss: ', array(-0.71922106, dtype=float32))
# (180, ' epoch, regularization loss: ', array(0.00937351, dtype=float32))
# (180, ' loss to real solution: ', 1.4775854820568843)
# (181, ' epoch, loss: ', array(-0.7422626, dtype=float32))
# (181, ' epoch, regularization loss: ', array(0.04801654, dtype=float32))
# (181, ' loss to real solution: ', 1.4222683463794243)
# (182, ' epoch, loss: ', array(-0.7747926, dtype=float32))
# (182, ' epoch, regularization loss: ', array(0.09224334, dtype=float32))
# (182, ' loss to real solution: ', 1.3712500398910312)
# (183, ' epoch, loss: ', array(-0.7235521, dtype=float32))
# (183, ' epoch, regularization loss: ', array(0.06545453, dtype=float32))
# (183, ' loss to real solution: ', 1.2711229384673752)
# (184, ' epoch, loss: ', array(-0.67779994, dtype=float32))
# (184, ' epoch, regularization loss: ', array(0.01862003, dtype=float32))
# (184, ' loss to real solution: ', 1.173525283282976)
# (185, ' epoch, loss: ', array(-0.6272954, dtype=float32))
# (185, ' epoch, regularization loss: ', array(0.00402478, dtype=float32))
# (185, ' loss to real solution: ', 1.1008581864067206)
# (186, ' epoch, loss: ', array(-0.6380863, dtype=float32))
# (186, ' epoch, regularization loss: ', array(0.01137597, dtype=float32))
# (186, ' loss to real solution: ', 1.0628442404891127)
# (187, ' epoch, loss: ', array(-0.6707362, dtype=float32))
# (187, ' epoch, regularization loss: ', array(0.04311271, dtype=float32))
# (187, ' loss to real solution: ', 1.0463296787301821)
# (188, ' epoch, loss: ', array(-0.6840722, dtype=float32))
# (188, ' epoch, regularization loss: ', array(0.06286829, dtype=float32))
# (188, ' loss to real solution: ', 1.0328075181402954)
# (189, ' epoch, loss: ', array(-0.6516614, dtype=float32))
# (189, ' epoch, regularization loss: ', array(0.03476918, dtype=float32))
# (189, ' loss to real solution: ', 1.005438727577399)
# (190, ' epoch, loss: ', array(-0.6037991, dtype=float32))
# (190, ' epoch, regularization loss: ', array(0.00945765, dtype=float32))
# (190, ' loss to real solution: ', 0.9788943742785804)
# (191, ' epoch, loss: ', array(-0.5975211, dtype=float32))
# (191, ' epoch, regularization loss: ', array(0.01785546, dtype=float32))
# (191, ' loss to real solution: ', 0.9708766199346521)
# (192, ' epoch, loss: ', array(-0.67615664, dtype=float32))
# (192, ' epoch, regularization loss: ', array(0.07727282, dtype=float32))
# (192, ' loss to real solution: ', 1.0034844073221993)
# (193, ' epoch, loss: ', array(-0.66799414, dtype=float32))
# (193, ' epoch, regularization loss: ', array(0.0587626, dtype=float32))
# (193, ' loss to real solution: ', 1.0143808669752628)
# (194, ' epoch, loss: ', array(-0.5854638, dtype=float32))
# (194, ' epoch, regularization loss: ', array(0.00764897, dtype=float32))
# (194, ' loss to real solution: ', 1.0092756555548048)
# (195, ' epoch, loss: ', array(-0.5821467, dtype=float32))
# (195, ' epoch, regularization loss: ', array(0.00181616, dtype=float32))
# (195, ' loss to real solution: ', 1.0226692971270948)
# (196, ' epoch, loss: ', array(-0.63248885, dtype=float32))
# (196, ' epoch, regularization loss: ', array(0.02562086, dtype=float32))
# (196, ' loss to real solution: ', 1.0646545004384689)
# (197, ' epoch, loss: ', array(-0.6444033, dtype=float32))
# (197, ' epoch, regularization loss: ', array(0.0672377, dtype=float32))
# (197, ' loss to real solution: ', 1.1030732550383375)
# (198, ' epoch, loss: ', array(-0.6358963, dtype=float32))
# (198, ' epoch, regularization loss: ', array(0.03963257, dtype=float32))
# (198, ' loss to real solution: ', 1.1111820830754522)
# (199, ' epoch, loss: ', array(-0.59973335, dtype=float32))
# (199, ' epoch, regularization loss: ', array(0.00698282, dtype=float32))
# (199, ' loss to real solution: ', 1.108315869059976)
# (200, ' epoch, loss: ', array(-0.57793957, dtype=float32))
# (200, ' epoch, regularization loss: ', array(0.00882128, dtype=float32))
# (200, ' loss to real solution: ', 1.1249653536943753)
# (201, ' epoch, loss: ', array(-0.6342048, dtype=float32))
# (201, ' epoch, regularization loss: ', array(0.04160119, dtype=float32))
# (201, ' loss to real solution: ', 1.1581323512842412)
# (202, ' epoch, loss: ', array(-0.65367377, dtype=float32))
# (202, ' epoch, regularization loss: ', array(0.05315188, dtype=float32))
# (202, ' loss to real solution: ', 1.1761655519974574)
# (203, ' epoch, loss: ', array(-0.6280047, dtype=float32))
# (203, ' epoch, regularization loss: ', array(0.03437024, dtype=float32))
# (203, ' loss to real solution: ', 1.1729810748606246)
# (204, ' epoch, loss: ', array(-0.7088805, dtype=float32))
# (204, ' epoch, regularization loss: ', array(0.17485498, dtype=float32))
# (204, ' loss to real solution: ', 1.2541000138678349)
# (205, ' epoch, loss: ', array(-0.67405766, dtype=float32))
# (205, ' epoch, regularization loss: ', array(0.06825194, dtype=float32))
# (205, ' loss to real solution: ', 1.2652165932823989)
# (206, ' epoch, loss: ', array(-0.6473032, dtype=float32))
# (206, ' epoch, regularization loss: ', array(0.00352411, dtype=float32))
# (206, ' loss to real solution: ', 1.2589135448802322)
# (207, ' epoch, loss: ', array(-0.6509765, dtype=float32))
# (207, ' epoch, regularization loss: ', array(0.00327831, dtype=float32))
# (207, ' loss to real solution: ', 1.2752160982840313)
# (208, ' epoch, loss: ', array(-0.70858014, dtype=float32))
# (208, ' epoch, regularization loss: ', array(0.02829941, dtype=float32))
# (208, ' loss to real solution: ', 1.2968608430305861)
# (209, ' epoch, loss: ', array(-0.75493747, dtype=float32))
# (209, ' epoch, regularization loss: ', array(0.0786121, dtype=float32))
# (209, ' loss to real solution: ', 1.3163636374665222)
# (210, ' epoch, loss: ', array(-0.74899614, dtype=float32))
# (210, ' epoch, regularization loss: ', array(0.06723217, dtype=float32))
# (210, ' loss to real solution: ', 1.3104485148747247)
# (211, ' epoch, loss: ', array(-0.69985855, dtype=float32))
# (211, ' epoch, regularization loss: ', array(0.01342311, dtype=float32))
# (211, ' loss to real solution: ', 1.2836449273682864)
# (212, ' epoch, loss: ', array(-0.7258348, dtype=float32))
# (212, ' epoch, regularization loss: ', array(0.01568523, dtype=float32))
# (212, ' loss to real solution: ', 1.2793937789243899)
# (213, ' epoch, loss: ', array(-0.7489289, dtype=float32))
# (213, ' epoch, regularization loss: ', array(0.02977802, dtype=float32))
# (213, ' loss to real solution: ', 1.2817645498372348)
# (214, ' epoch, loss: ', array(-0.76468575, dtype=float32))
# (214, ' epoch, regularization loss: ', array(0.03638477, dtype=float32))
# (214, ' loss to real solution: ', 1.2802934996338133)
# (215, ' epoch, loss: ', array(-0.7800519, dtype=float32))
# (215, ' epoch, regularization loss: ', array(0.02379975, dtype=float32))
# (215, ' loss to real solution: ', 1.2712351685513252)
# (216, ' epoch, loss: ', array(-0.7921313, dtype=float32))
# (216, ' epoch, regularization loss: ', array(0.03933492, dtype=float32))
# (216, ' loss to real solution: ', 1.272547205445084)
# (217, ' epoch, loss: ', array(-0.78713053, dtype=float32))
# (217, ' epoch, regularization loss: ', array(0.03535981, dtype=float32))
# (217, ' loss to real solution: ', 1.2699476199671385)
# (218, ' epoch, loss: ', array(-0.7730276, dtype=float32))
# (218, ' epoch, regularization loss: ', array(0.0174327, dtype=float32))
# (218, ' loss to real solution: ', 1.2604883215396732)
# (219, ' epoch, loss: ', array(-0.7631254, dtype=float32))
# (219, ' epoch, regularization loss: ', array(0.0087906, dtype=float32))
# (219, ' loss to real solution: ', 1.2552857286830421)
# (220, ' epoch, loss: ', array(-0.7758386, dtype=float32))
# (220, ' epoch, regularization loss: ', array(0.0188215, dtype=float32))
# (220, ' loss to real solution: ', 1.2621611651845297)
# (221, ' epoch, loss: ', array(-0.7923926, dtype=float32))
# (221, ' epoch, regularization loss: ', array(0.03367861, dtype=float32))
# (221, ' loss to real solution: ', 1.271753889375944)
# (222, ' epoch, loss: ', array(-0.79080915, dtype=float32))
# (222, ' epoch, regularization loss: ', array(0.02840522, dtype=float32))
# (222, ' loss to real solution: ', 1.2745653111030049)
# (223, ' epoch, loss: ', array(-0.77434355, dtype=float32))
# (223, ' epoch, regularization loss: ', array(0.01308685, dtype=float32))
# (223, ' loss to real solution: ', 1.2746038562385213)
# (224, ' epoch, loss: ', array(-0.77708834, dtype=float32))
# (224, ' epoch, regularization loss: ', array(0.01279886, dtype=float32))
# (224, ' loss to real solution: ', 1.2837627474479734)
# (225, ' epoch, loss: ', array(-0.7986981, dtype=float32))
# (225, ' epoch, regularization loss: ', array(0.03842597, dtype=float32))
# (225, ' loss to real solution: ', 1.3053167407688984)
# (226, ' epoch, loss: ', array(-0.79543185, dtype=float32))
# (226, ' epoch, regularization loss: ', array(0.03342449, dtype=float32))
# (226, ' loss to real solution: ', 1.3155392878845187)
# (227, ' epoch, loss: ', array(-0.77524346, dtype=float32))
# (227, ' epoch, regularization loss: ', array(0.00930998, dtype=float32))
# (227, ' loss to real solution: ', 1.3169264183895377)
# (228, ' epoch, loss: ', array(-0.7256546, dtype=float32))
# (228, ' epoch, regularization loss: ', array(0.00623149, dtype=float32))
# (228, ' loss to real solution: ', 1.3325205779688918)
# (229, ' epoch, loss: ', array(-0.7539542, dtype=float32))
# (229, ' epoch, regularization loss: ', array(0.03239419, dtype=float32))
# (229, ' loss to real solution: ', 1.3672041730060454)
# (230, ' epoch, loss: ', array(-0.7527662, dtype=float32))
# (230, ' epoch, regularization loss: ', array(0.03458351, dtype=float32))
# (230, ' loss to real solution: ', 1.3884078312111823)
# (231, ' epoch, loss: ', array(-0.692257, dtype=float32))
# (231, ' epoch, regularization loss: ', array(0.00471021, dtype=float32))
# (231, ' loss to real solution: ', 1.3918460191599427)
# (232, ' epoch, loss: ', array(-0.70250744, dtype=float32))
# (232, ' epoch, regularization loss: ', array(0.02136116, dtype=float32))
# (232, ' loss to real solution: ', 1.4235135846735962)
# (233, ' epoch, loss: ', array(-0.70458806, dtype=float32))
# (233, ' epoch, regularization loss: ', array(0.04661573, dtype=float32))
# (233, ' loss to real solution: ', 1.4573707116723444)
# (234, ' epoch, loss: ', array(-0.64168155, dtype=float32))
# (234, ' epoch, regularization loss: ', array(0.00641757, dtype=float32))
# (234, ' loss to real solution: ', 1.463446250870297)
# (235, ' epoch, loss: ', array(-0.6417423, dtype=float32))
# (235, ' epoch, regularization loss: ', array(0.01935645, dtype=float32))
# (235, ' loss to real solution: ', 1.5016076714241235)
# (236, ' epoch, loss: ', array(-0.6570756, dtype=float32))
# (236, ' epoch, regularization loss: ', array(0.04543119, dtype=float32))
# (236, ' loss to real solution: ', 1.547023215569867)
# (237, ' epoch, loss: ', array(-0.60219824, dtype=float32))
# (237, ' epoch, regularization loss: ', array(0.00454402, dtype=float32))
# (237, ' loss to real solution: ', 1.5610898142803904)
# (238, ' epoch, loss: ', array(-0.6750293, dtype=float32))
# (238, ' epoch, regularization loss: ', array(0.03830095, dtype=float32))
# (238, ' loss to real solution: ', 1.62274995771635)
# (239, ' epoch, loss: ', array(-0.7315092, dtype=float32))
# (239, ' epoch, regularization loss: ', array(0.03656769, dtype=float32))
# (239, ' loss to real solution: ', 1.662066038873801)
# (240, ' epoch, loss: ', array(-0.7658621, dtype=float32))
# (240, ' epoch, regularization loss: ', array(0.0787729, dtype=float32))
# (240, ' loss to real solution: ', 1.6710704218114687)
# (241, ' epoch, loss: ', array(-0.5951109, dtype=float32))
# (241, ' epoch, regularization loss: ', array(0., dtype=float32))
# (241, ' loss to real solution: ', 1.589276184410911)
# (242, ' epoch, loss: ', array(-0.66673255, dtype=float32))
# (242, ' epoch, regularization loss: ', array(0.00567579, dtype=float32))
# (242, ' loss to real solution: ', 1.6076084404091358)
# (243, ' epoch, loss: ', array(-0.7952622, dtype=float32))
# (243, ' epoch, regularization loss: ', array(0.27194786, dtype=float32))
# (243, ' loss to real solution: ', 1.6691201960695516)
# (244, ' epoch, loss: ', array(-0.58527917, dtype=float32))
# (244, ' epoch, regularization loss: ', array(0., dtype=float32))
# (244, ' loss to real solution: ', 1.544075126046153)
# (245, ' epoch, loss: ', array(-0.5160406, dtype=float32))
# (245, ' epoch, regularization loss: ', array(0., dtype=float32))
# (245, ' loss to real solution: ', 1.5006056644487227)
# (246, ' epoch, loss: ', array(-0.604171, dtype=float32))
# (246, ' epoch, regularization loss: ', array(0., dtype=float32))
# (246, ' loss to real solution: ', 1.5281119366704075)
# (247, ' epoch, loss: ', array(-0.82038313, dtype=float32))
# (247, ' epoch, regularization loss: ', array(0.29666665, dtype=float32))
# (247, ' loss to real solution: ', 1.6188901208566315)
# (248, ' epoch, loss: ', array(-0.65619993, dtype=float32))
# (248, ' epoch, regularization loss: ', array(0.0067837, dtype=float32))
# (248, ' loss to real solution: ', 1.5268935943493123)
# (249, ' epoch, loss: ', array(-0.56707233, dtype=float32))
# (249, ' epoch, regularization loss: ', array(0., dtype=float32))
# (249, ' loss to real solution: ', 1.467529530019239)
# (250, ' epoch, loss: ', array(-0.6037144, dtype=float32))
# (250, ' epoch, regularization loss: ', array(0., dtype=float32))
# (250, ' loss to real solution: ', 1.4720385285397435)
# (251, ' epoch, loss: ', array(-0.76491874, dtype=float32))
# (251, ' epoch, regularization loss: ', array(0.2180721, dtype=float32))
# (251, ' loss to real solution: ', 1.5299959733708495)
# (252, ' epoch, loss: ', array(-0.6599496, dtype=float32))
# (252, ' epoch, regularization loss: ', array(0.0187362, dtype=float32))
# (252, ' loss to real solution: ', 1.45386963919428)
# (253, ' epoch, loss: ', array(-0.80818486, dtype=float32))
# (253, ' epoch, regularization loss: ', array(0.22019178, dtype=float32))
# (253, ' loss to real solution: ', 1.473671539607922)
# (254, ' epoch, loss: ', array(-0.7511523, dtype=float32))
# (254, ' epoch, regularization loss: ', array(0.03119932, dtype=float32))
# (254, ' loss to real solution: ', 1.3912241909243288)
# (255, ' epoch, loss: ', array(-0.6807659, dtype=float32))
# (255, ' epoch, regularization loss: ', array(0., dtype=float32))
# (255, ' loss to real solution: ', 1.306343359479567)
# (256, ' epoch, loss: ', array(-0.6901709, dtype=float32))
# (256, ' epoch, regularization loss: ', array(0., dtype=float32))
# (256, ' loss to real solution: ', 1.26878100259511)
# (257, ' epoch, loss: ', array(-0.7617729, dtype=float32))
# (257, ' epoch, regularization loss: ', array(0.00030079, dtype=float32))
# (257, ' loss to real solution: ', 1.2692519688874577)
# (258, ' epoch, loss: ', array(-0.8593223, dtype=float32))
# (258, ' epoch, regularization loss: ', array(0.13781765, dtype=float32))
# (258, ' loss to real solution: ', 1.2963518469624964)
# (259, ' epoch, loss: ', array(-0.8453957, dtype=float32))
# (259, ' epoch, regularization loss: ', array(0.09036309, dtype=float32))
# (259, ' loss to real solution: ', 1.2636837693809313)
# (260, ' epoch, loss: ', array(-0.7517081, dtype=float32))
# (260, ' epoch, regularization loss: ', array(0., dtype=float32))
# (260, ' loss to real solution: ', 1.1981767381464168)
# (261, ' epoch, loss: ', array(-0.7438314, dtype=float32))
# (261, ' epoch, regularization loss: ', array(0., dtype=float32))
# ...
# (313, ' epoch, regularization loss: ', array(0.18564752, dtype=float32))
# (313, ' loss to real solution: ', 1.136714013822592)
# (314, ' epoch, loss: ', array(-0.73523635, dtype=float32))
# (314, ' epoch, regularization loss: ', array(0., dtype=float32))
# (314, ' loss to real solution: ', 1.082385550449898)
# (315, ' epoch, loss: ', array(-0.7195092, dtype=float32))
# (315, ' epoch, regularization loss: ', array(0., dtype=float32))
# (315, ' loss to real solution: ', 1.0706678128664127)
# (316, ' epoch, loss: ', array(-0.7262386, dtype=float32))
# (316, ' epoch, regularization loss: ', array(0., dtype=float32))
# (316, ' loss to real solution: ', 1.0680515988425037)
# (317, ' epoch, loss: ', array(-0.7324031, dtype=float32))
# (317, ' epoch, regularization loss: ', array(0., dtype=float32))
# (317, ' loss to real solution: ', 1.074569759736873)
# (318, ' epoch, loss: ', array(-0.7510849, dtype=float32))
# (318, ' epoch, regularization loss: ', array(0., dtype=float32))
# (318, ' loss to real solution: ', 1.088378207856052)
# (319, ' epoch, loss: ', array(-0.77522993, dtype=float32))
# (319, ' epoch, regularization loss: ', array(0.01402318, dtype=float32))
# (319, ' loss to real solution: ', 1.1087637730503384)
# (320, ' epoch, loss: ', array(-0.8047321, dtype=float32))
# (320, ' epoch, regularization loss: ', array(0.05333804, dtype=float32))
# (320, ' loss to real solution: ', 1.1254754429614808)
# (321, ' epoch, loss: ', array(-0.8085474, dtype=float32))
# (321, ' epoch, regularization loss: ', array(0.04903849, dtype=float32))
# (321, ' loss to real solution: ', 1.1296558170226605)
# (322, ' epoch, loss: ', array(-0.79389197, dtype=float32))
# (322, ' epoch, regularization loss: ', array(0.0112316, dtype=float32))
# (322, ' loss to real solution: ', 1.1232510241626539)
# (323, ' epoch, loss: ', array(-0.7790625, dtype=float32))
# (323, ' epoch, regularization loss: ', array(0., dtype=float32))
# (323, ' loss to real solution: ', 1.116716952277916)
# (324, ' epoch, loss: ', array(-0.7742387, dtype=float32))
# (324, ' epoch, regularization loss: ', array(0., dtype=float32))
# (324, ' loss to real solution: ', 1.1190337000130837)
# (325, ' epoch, loss: ', array(-0.78229105, dtype=float32))
# (325, ' epoch, regularization loss: ', array(0., dtype=float32))
# (325, ' loss to real solution: ', 1.1291595891894246)
# (326, ' epoch, loss: ', array(-0.7968295, dtype=float32))
# (326, ' epoch, regularization loss: ', array(0.00108113, dtype=float32))
# (326, ' loss to real solution: ', 1.1463882833968402)
# (327, ' epoch, loss: ', array(-0.8234909, dtype=float32))
# (327, ' epoch, regularization loss: ', array(0.02734989, dtype=float32))
# (327, ' loss to real solution: ', 1.1694577844158243)
# (328, ' epoch, loss: ', array(-0.83830786, dtype=float32))
# (328, ' epoch, regularization loss: ', array(0.0475722, dtype=float32))
# (328, ' loss to real solution: ', 1.1833261687425938)
# (329, ' epoch, loss: ', array(-0.8264056, dtype=float32))
# (329, ' epoch, regularization loss: ', array(0.02113733, dtype=float32))
# (329, ' loss to real solution: ', 1.1844707220466957)
# (330, ' epoch, loss: ', array(-0.8060825, dtype=float32))
# (330, ' epoch, regularization loss: ', array(0.00036507, dtype=float32))
# (330, ' loss to real solution: ', 1.1805861767618602)
# (331, ' epoch, loss: ', array(-0.7995731, dtype=float32))
# (331, ' epoch, regularization loss: ', array(0., dtype=float32))
# (331, ' loss to real solution: ', 1.1835848962149051)
# (332, ' epoch, loss: ', array(-0.80390745, dtype=float32))
# (332, ' epoch, regularization loss: ', array(0., dtype=float32))
# (332, ' loss to real solution: ', 1.1942768082511386)
# (333, ' epoch, loss: ', array(-0.8184328, dtype=float32))
# (333, ' epoch, regularization loss: ', array(0.00321629, dtype=float32))
# (333, ' loss to real solution: ', 1.2123597498070389)
# (334, ' epoch, loss: ', array(-0.83611286, dtype=float32))
# (334, ' epoch, regularization loss: ', array(0.02418695, dtype=float32))
# (334, ' loss to real solution: ', 1.2314902468279627)
# (335, ' epoch, loss: ', array(-0.8397215, dtype=float32))
# (335, ' epoch, regularization loss: ', array(0.02550506, dtype=float32))
# (335, ' loss to real solution: ', 1.241980751703023)
# (336, ' epoch, loss: ', array(-0.8295859, dtype=float32))
# (336, ' epoch, regularization loss: ', array(0.00550972, dtype=float32))
# (336, ' loss to real solution: ', 1.2441227928580194)
# (337, ' epoch, loss: ', array(-0.819503, dtype=float32))
# (337, ' epoch, regularization loss: ', array(0.00012133, dtype=float32))
# (337, ' loss to real solution: ', 1.247209206842533)
# (338, ' epoch, loss: ', array(-0.82255113, dtype=float32))
# (338, ' epoch, regularization loss: ', array(0.00023226, dtype=float32))
# (338, ' loss to real solution: ', 1.2572390496500816)
# (339, ' epoch, loss: ', array(-0.8327679, dtype=float32))
# (339, ' epoch, regularization loss: ', array(0.00590977, dtype=float32))
# (339, ' loss to real solution: ', 1.2731948697068682)
# (340, ' epoch, loss: ', array(-0.84542286, dtype=float32))
# (340, ' epoch, regularization loss: ', array(0.01777777, dtype=float32))
# (340, ' loss to real solution: ', 1.2888580782007173)
# (341, ' epoch, loss: ', array(-0.8517468, dtype=float32))
# (341, ' epoch, regularization loss: ', array(0.01978985, dtype=float32))
# (341, ' loss to real solution: ', 1.2989319395175698)
# (342, ' epoch, loss: ', array(-0.84588164, dtype=float32))
# (342, ' epoch, regularization loss: ', array(0.00520438, dtype=float32))
# (342, ' loss to real solution: ', 1.3018982251319084)
# (343, ' epoch, loss: ', array(-0.8338509, dtype=float32))
# (343, ' epoch, regularization loss: ', array(7.4401054e-05, dtype=float32))
# (343, ' loss to real solution: ', 1.3054631718446967)
# (344, ' epoch, loss: ', array(-0.8384014, dtype=float32))
# (344, ' epoch, regularization loss: ', array(0.00073562, dtype=float32))
# (344, ' loss to real solution: ', 1.3162267256933007)
# (345, ' epoch, loss: ', array(-0.8513631, dtype=float32))
# (345, ' epoch, regularization loss: ', array(0.00987312, dtype=float32))
# (345, ' loss to real solution: ', 1.3315305798920019)
# (346, ' epoch, loss: ', array(-0.858207, dtype=float32))
# (346, ' epoch, regularization loss: ', array(0.01814142, dtype=float32))
# (346, ' loss to real solution: ', 1.3435127003936522)
# (347, ' epoch, loss: ', array(-0.8492624, dtype=float32))
# (347, ' epoch, regularization loss: ', array(0.00947702, dtype=float32))
# (347, ' loss to real solution: ', 1.348647646194869)
# (348, ' epoch, loss: ', array(-0.8388195, dtype=float32))
# (348, ' epoch, regularization loss: ', array(0.00169125, dtype=float32))
# (348, ' loss to real solution: ', 1.3515343082449445)
# (349, ' epoch, loss: ', array(-0.8390248, dtype=float32))
# (349, ' epoch, regularization loss: ', array(0.00071165, dtype=float32))
# (349, ' loss to real solution: ', 1.358787725876382)
# (350, ' epoch, loss: ', array(-0.84500545, dtype=float32))
# (350, ' epoch, regularization loss: ', array(0.00507062, dtype=float32))
# (350, ' loss to real solution: ', 1.3712575139493421)
# (351, ' epoch, loss: ', array(-0.85537004, dtype=float32))
# (351, ' epoch, regularization loss: ', array(0.01535869, dtype=float32))
# (351, ' loss to real solution: ', 1.383573252572124)
# (352, ' epoch, loss: ', array(-0.8534048, dtype=float32))
# (352, ' epoch, regularization loss: ', array(0.01010752, dtype=float32))
# (352, ' loss to real solution: ', 1.3892947931726645)
# (353, ' epoch, loss: ', array(-0.83819956, dtype=float32))
# (353, ' epoch, regularization loss: ', array(0.00144625, dtype=float32))
# (353, ' loss to real solution: ', 1.3916446875107633)
# (354, ' epoch, loss: ', array(-0.83730304, dtype=float32))
# (354, ' epoch, regularization loss: ', array(0.00085323, dtype=float32))
# (354, ' loss to real solution: ', 1.3983637008214687)
# (355, ' epoch, loss: ', array(-0.8462753, dtype=float32))
# (355, ' epoch, regularization loss: ', array(0.00695471, dtype=float32))
# (355, ' loss to real solution: ', 1.4101271825741342)
# (356, ' epoch, loss: ', array(-0.8564769, dtype=float32))
# (356, ' epoch, regularization loss: ', array(0.0148738, dtype=float32))
# (356, ' loss to real solution: ', 1.4201537661958739)
# (357, ' epoch, loss: ', array(-0.8490897, dtype=float32))
# (357, ' epoch, regularization loss: ', array(0.00849519, dtype=float32))
# (357, ' loss to real solution: ', 1.4235559335820545)
# (358, ' epoch, loss: ', array(-0.8475401, dtype=float32))
# (358, ' epoch, regularization loss: ', array(0.00143886, dtype=float32))
# (358, ' loss to real solution: ', 1.4245198538602357)
# (359, ' epoch, loss: ', array(-0.84829575, dtype=float32))
# (359, ' epoch, regularization loss: ', array(0.00169746, dtype=float32))
# (359, ' loss to real solution: ', 1.4304341100764812)
# (360, ' epoch, loss: ', array(-0.86043215, dtype=float32))
# (360, ' epoch, regularization loss: ', array(0.00886795, dtype=float32))
# (360, ' loss to real solution: ', 1.4400833195390426)
# (361, ' epoch, loss: ', array(-0.8645864, dtype=float32))
# (361, ' epoch, regularization loss: ', array(0.01035445, dtype=float32))
# (361, ' loss to real solution: ', 1.445635928789519)
# (362, ' epoch, loss: ', array(-0.8569436, dtype=float32))
# (362, ' epoch, regularization loss: ', array(0.00417053, dtype=float32))
# (362, ' loss to real solution: ', 1.4470829373348948)
# (363, ' epoch, loss: ', array(-0.85385424, dtype=float32))
# (363, ' epoch, regularization loss: ', array(0.00399856, dtype=float32))
# (363, ' loss to real solution: ', 1.4501787835148754)
# (364, ' epoch, loss: ', array(-0.8525204, dtype=float32))
# (364, ' epoch, regularization loss: ', array(0.00744982, dtype=float32))
# (364, ' loss to real solution: ', 1.454697026888274)
# (365, ' epoch, loss: ', array(-0.8431162, dtype=float32))
# (365, ' epoch, regularization loss: ', array(0.00677718, dtype=float32))
# (365, ' loss to real solution: ', 1.4566700903127432)
# (366, ' epoch, loss: ', array(-0.83961856, dtype=float32))
# (366, ' epoch, regularization loss: ', array(0.00343039, dtype=float32))
# (366, ' loss to real solution: ', 1.4568492245980782)
# (367, ' epoch, loss: ', array(-0.8357451, dtype=float32))
# (367, ' epoch, regularization loss: ', array(0.00337957, dtype=float32))
# (367, ' loss to real solution: ', 1.4590262545420043)
# (368, ' epoch, loss: ', array(-0.83839595, dtype=float32))
# (368, ' epoch, regularization loss: ', array(0.00828519, dtype=float32))
# (368, ' loss to real solution: ', 1.4638003079224247)
# (369, ' epoch, loss: ', array(-0.83568484, dtype=float32))
# (369, ' epoch, regularization loss: ', array(0.00633899, dtype=float32))
# (369, ' loss to real solution: ', 1.4650785454369817)
# (370, ' epoch, loss: ', array(-0.8323557, dtype=float32))
# (370, ' epoch, regularization loss: ', array(0.00248587, dtype=float32))
# (370, ' loss to real solution: ', 1.4648576213960862)
# (371, ' epoch, loss: ', array(-0.8302577, dtype=float32))
# (371, ' epoch, regularization loss: ', array(0.00357732, dtype=float32))
# (371, ' loss to real solution: ', 1.4672979488211813)
# (372, ' epoch, loss: ', array(-0.83109766, dtype=float32))
# (372, ' epoch, regularization loss: ', array(0.00788529, dtype=float32))
# (372, ' loss to real solution: ', 1.471448570677705)
# (373, ' epoch, loss: ', array(-0.83658415, dtype=float32))
# (373, ' epoch, regularization loss: ', array(0.00782606, dtype=float32))
# (373, ' loss to real solution: ', 1.4727877391841249)
# (374, ' epoch, loss: ', array(-0.8303041, dtype=float32))
# (374, ' epoch, regularization loss: ', array(0.00253889, dtype=float32))
# (374, ' loss to real solution: ', 1.4711477502519295)
# (375, ' epoch, loss: ', array(-0.8329577, dtype=float32))
# (375, ' epoch, regularization loss: ', array(0.00344675, dtype=float32))
# (375, ' loss to real solution: ', 1.4731473065994176)
# (376, ' epoch, loss: ', array(-0.8370594, dtype=float32))
# (376, ' epoch, regularization loss: ', array(0.00776201, dtype=float32))
# (376, ' loss to real solution: ', 1.476630468552519)
# (377, ' epoch, loss: ', array(-0.8418125, dtype=float32))
# (377, ' epoch, regularization loss: ', array(0.00492704, dtype=float32))
# (377, ' loss to real solution: ', 1.4758532720900042)
# (378, ' epoch, loss: ', array(-0.8369588, dtype=float32))
# (378, ' epoch, regularization loss: ', array(0.00272121, dtype=float32))
# (378, ' loss to real solution: ', 1.4708349509216196)
# (379, ' epoch, loss: ', array(-0.83464926, dtype=float32))
# (379, ' epoch, regularization loss: ', array(0.00877748, dtype=float32))
# (379, ' loss to real solution: ', 1.4701771896138451)
# (380, ' epoch, loss: ', array(-0.8212056, dtype=float32))
# (380, ' epoch, regularization loss: ', array(0.00731233, dtype=float32))
# (380, ' loss to real solution: ', 1.466352926569353)
# (381, ' epoch, loss: ', array(-0.81669366, dtype=float32))
# (381, ' epoch, regularization loss: ', array(0.00315506, dtype=float32))
# (381, ' loss to real solution: ', 1.4611752347509193)
# (382, ' epoch, loss: ', array(-0.8190421, dtype=float32))
# (382, ' epoch, regularization loss: ', array(0.00320044, dtype=float32))
# (382, ' loss to real solution: ', 1.459152147409617)
# (383, ' epoch, loss: ', array(-0.8205207, dtype=float32))
# (383, ' epoch, regularization loss: ', array(0.0076155, dtype=float32))
# (383, ' loss to real solution: ', 1.4598444992476336)
# (384, ' epoch, loss: ', array(-0.8202771, dtype=float32))
# (384, ' epoch, regularization loss: ', array(0.00556927, dtype=float32))
# (384, ' loss to real solution: ', 1.4578291904083018)
# (385, ' epoch, loss: ', array(-0.81822515, dtype=float32))
# (385, ' epoch, regularization loss: ', array(0.00238753, dtype=float32))
# (385, ' loss to real solution: ', 1.4553184419161254)
# (386, ' epoch, loss: ', array(-0.8198679, dtype=float32))
# (386, ' epoch, regularization loss: ', array(0.00494602, dtype=float32))
# (386, ' loss to real solution: ', 1.4567465145833238)
# (387, ' epoch, loss: ', array(-0.81792706, dtype=float32))
# (387, ' epoch, regularization loss: ', array(0.00624625, dtype=float32))
# (387, ' loss to real solution: ', 1.4533274157407583)
# (388, ' epoch, loss: ', array(-0.8142781, dtype=float32))
# (388, ' epoch, regularization loss: ', array(0.00681863, dtype=float32))
# (388, ' loss to real solution: ', 1.4491685562731753)
# (389, ' epoch, loss: ', array(-0.8056345, dtype=float32))
# (389, ' epoch, regularization loss: ', array(0.00296199, dtype=float32))
# (389, ' loss to real solution: ', 1.4435741390599317)
# (390, ' epoch, loss: ', array(-0.804266, dtype=float32))
# (390, ' epoch, regularization loss: ', array(0.00449595, dtype=float32))
# (390, ' loss to real solution: ', 1.4411648016420593)
# (391, ' epoch, loss: ', array(-0.8034767, dtype=float32))
# (391, ' epoch, regularization loss: ', array(0.00690422, dtype=float32))
# (391, ' loss to real solution: ', 1.439864140036022)
# (392, ' epoch, loss: ', array(-0.803498, dtype=float32))
# (392, ' epoch, regularization loss: ', array(0.00505389, dtype=float32))
# (392, ' loss to real solution: ', 1.4369924084703256)
# (393, ' epoch, loss: ', array(-0.8032622, dtype=float32))
# (393, ' epoch, regularization loss: ', array(0.00359801, dtype=float32))
# (393, ' loss to real solution: ', 1.434880751501709)
# (394, ' epoch, loss: ', array(-0.8037222, dtype=float32))
# (394, ' epoch, regularization loss: ', array(0.00635395, dtype=float32))
# (394, ' loss to real solution: ', 1.434910318855304)
# (395, ' epoch, loss: ', array(-0.8053526, dtype=float32))
# (395, ' epoch, regularization loss: ', array(0.00507225, dtype=float32))
# (395, ' loss to real solution: ', 1.4332936837320542)
# (396, ' epoch, loss: ', array(-0.8073964, dtype=float32))
# (396, ' epoch, regularization loss: ', array(0.00274353, dtype=float32))
# (396, ' loss to real solution: ', 1.431572140888386)
# (397, ' epoch, loss: ', array(-0.8096027, dtype=float32))
# (397, ' epoch, regularization loss: ', array(0.0044307, dtype=float32))
# (397, ' loss to real solution: ', 1.4328883768431244)
# (398, ' epoch, loss: ', array(-0.7900067, dtype=float32))
# (398, ' epoch, regularization loss: ', array(0.00732941, dtype=float32))
# (398, ' loss to real solution: ', 1.4344435461617744)
# (399, ' epoch, loss: ', array(-0.78361636, dtype=float32))
# (399, ' epoch, regularization loss: ', array(0.00301422, dtype=float32))
# (399, ' loss to real solution: ', 1.432433145314551)

# %%
scheduler = MultiStepLR(optimizer, milestones=[400], gamma=0.1)
from time import *
start = time()              
for k in range(10):
    n1 = 0
    loss = torch.zeros(1)
    for i in range(xl):
        for j in range(yl):        
            x_input = np.zeros(m)
            x_input[0] = xs[i, j]
            x_input[1] = ys[i, j]
            if x_input[0] ** 2 + x_input[1] ** 2 < 1:
                n1 += 1
                x_input = torch.tensor(x_input).float()
                y = model(x_input)
                
                x1 = torch.zeros(m)
                x2 = torch.zeros(m)
                x1[0] = 0.0001
                x2[1] = 0.0001
                x_input_1 = x_input.float() + x1
                x_input_2 = x_input.float() + x2
                x_input_3 = x_input.float() - x1
                x_input_4 = x_input.float() - x2
                x_input_grad_1 = (model(x_input_1) - y) / 0.0001
                x_input_grad_2 = (model(x_input_2) - y) / 0.0001
                x_input_2_grad_x = (model(x_input_1) + model(x_input_3) - 2 * y) / 0.0001**2
                x_input_2_grad_y = (model(x_input_2) + model(x_input_4) - 2 * y) / 0.0001**2

                loss += 0.5 * ((x_input_grad_1) ** 2 + (x_input_grad_2) ** 2) - y 
    loss /= n1
    
    regularization = torch.zeros(1)
    for t in range(n2):
        theta = t / n2 * (2 * pi)
        x_input = np.zeros(m)
        x_input[0] = cos(theta)
        x_input[1] = sin(theta)
        x_input = torch.tensor(x_input).float()
        y = model(x_input)
        regularization += y**2 
    regularization *= mm / n2
    if gamma < 500:
        gamma = gamma * 1.01
    if mm < 500:
        mm = mm * 1.01
        
    print(k, " epoch, loss: ", loss.data[0].numpy())
    print(k, " epoch, regularization loss: ", regularization.data[0].numpy())
    print(k, " loss to real solution: ", cal_loss(model))
    if cal_loss(model) < 0.0001:
        break
    
    loss += regularization
    
    optimizer.zero_grad()
    loss.backward()
    
    scheduler.step()
    optimizer.step()
stop = time()
print(stop - start)
# Out:
# (0, ' epoch, loss: ', array(-0.7830908, dtype=float32))
# (0, ' epoch, regularization loss: ', array(0.00349998, dtype=float32))
# (0, ' loss to real solution: ', 1.4330135437223306)
# (1, ' epoch, loss: ', array(-0.7879697, dtype=float32))
# (1, ' epoch, regularization loss: ', array(0.00710402, dtype=float32))
# (1, ' loss to real solution: ', 1.4351244984677367)
# (2, ' epoch, loss: ', array(-0.7814055, dtype=float32))
# (2, ' epoch, regularization loss: ', array(0.00064956, dtype=float32))
# (2, ' loss to real solution: ', 1.4289390586541781)
# (3, ' epoch, loss: ', array(-0.7718118, dtype=float32))
# (3, ' epoch, regularization loss: ', array(0.00589034, dtype=float32))
# (3, ' loss to real solution: ', 1.423790562283188)
# (4, ' epoch, loss: ', array(-0.7633854, dtype=float32))
# (4, ' epoch, regularization loss: ', array(0.00849598, dtype=float32))
# (4, ' loss to real solution: ', 1.417541568585914)
# (5, ' epoch, loss: ', array(-0.7479438, dtype=float32))
# (5, ' epoch, regularization loss: ', array(0.00115804, dtype=float32))
# (5, ' loss to real solution: ', 1.4072359015473983)
# (6, ' epoch, loss: ', array(-0.74448925, dtype=float32))
# (6, ' epoch, regularization loss: ', array(0.00433618, dtype=float32))
# (6, ' loss to real solution: ', 1.40395388696738)
# (7, ' epoch, loss: ', array(-0.74307305, dtype=float32))
# (7, ' epoch, regularization loss: ', array(0.00871984, dtype=float32))
# (7, ' loss to real solution: ', 1.401258990404307)
# (8, ' epoch, loss: ', array(-0.7354958, dtype=float32))
# (8, ' epoch, regularization loss: ', array(0.00186041, dtype=float32))
# (8, ' loss to real solution: ', 1.3938546886934726)
# (9, ' epoch, loss: ', array(-0.73355305, dtype=float32))
# (9, ' epoch, regularization loss: ', array(0.0029577, dtype=float32))
# (9, ' loss to real solution: ', 1.391439032895772)
# 37.5220410824

# %%
validate(the_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a2477b96a0f1> in <module>()
# ----> 1 validate(the_model)
#
# <ipython-input-6-035508cd3b17> in validate(mod)
#       1 def validate(mod):
# ----> 2     draw_graph(mod)
#       3     print(cal_loss(mod))
#
# TypeError: draw_graph() takes exactly 2 arguments (1 given)

# %%
relative_err(the_model)

# %%
PATH = 'test_parameters.pkl'
torch.save(the_model.state_dict(), PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8b43a4027aa5> in <module>()
#       1 PATH = 'test_parameters.pkl'
# ----> 2 torch.save(the_model.state_dict(), PATH)
#
# NameError: name 'the_model' is not defined

# %%
m = 10
PATH = 'test_parameters.pkl'
the_model = DeepRitzNet(m)
the_model.load_state_dict(torch.load(PATH))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-13-903a4fc8859d> in <module>()
#       2 PATH = 'test_parameters.pkl'
#       3 the_model = DeepRitzNet(m)
# ----> 4 the_model.load_state_dict(torch.load(PATH))
#
# /home/samim/anaconda2/lib/python2.7/site-packages/torch/serialization.pyc in load(f, map_location, pickle_module, **pickle_load_args)
#     380             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     381         new_fd = True
# --> 382         f = open(f, 'rb')
#     383     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     384         new_fd = True
#
# IOError: [Errno 2] No such file or directory: 'test_parameters.pkl'

# %%
train(the_model, initial_lr=0.001*learning_rate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f025477bd0d2> in <module>()
# ----> 1 train(the_model, initial_lr=0.001*learning_rate)
#
# <ipython-input-12-8c08ff716b21> in train(mod, initial_lr, milestones, gamma, iterations, mm)
#      10     xl, yl = xs.size()
#      11
# ---> 12     start = time.time()
#      13     for k in range(iterations):
#      14         n1 = 0
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'time'

# %%
def train(mod, initial_lr=learning_rate, milestones=[400], gamma=0.1, iterations=iterations, mm=1):
    optimizer = torch.optim.Adam(mod.parameters(), lr=initial_lr)
    scheduler = MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

    mm = 1
    points = np.arange(-1, 1, 0.1)
    xs, ys = np.meshgrid(points, points)
    xs = torch.tensor(xs)
    ys = torch.tensor(ys)
    xl, yl = xs.size()

    start = time.time()
    for k in range(iterations):
        n1 = 0
        loss = torch.zeros(1)
        for i in range(xl):
            for j in range(yl):        
                x_input = np.zeros(m)
                x_input[0] = xs[i, j]
                x_input[1] = ys[i, j]
                if x_input[0] ** 2 + x_input[1] ** 2 < 1:
                    n1 += 1
                    x_input = torch.tensor(x_input).float()
                    y = mod(x_input)

                    x1 = torch.zeros(m)
                    x2 = torch.zeros(m)
                    x1[0] = 0.0001
                    x2[1] = 0.0001
                    x_input_1 = x_input.float() + x1
                    x_input_2 = x_input.float() + x2
                    x_input_3 = x_input.float() - x1
                    x_input_4 = x_input.float() - x2
                    x_input_grad_1 = (mod(x_input_1) - y) / 0.0001
                    x_input_grad_2 = (mod(x_input_2) - y) / 0.0001
                    x_input_2_grad_x = (mod(x_input_1) + the_model(x_input_3) - 2 * y) / 0.0001**2
                    x_input_2_grad_y = (mod(x_input_2) + the_model(x_input_4) - 2 * y) / 0.0001**2

                    loss += 0.5 * ((x_input_grad_1) ** 2 + (x_input_grad_2) ** 2) + y
        loss /= n1

        regularization = torch.zeros(1)
        for t in range(n2):
            theta = t / n2 * (2 * pi)
            x_input = np.zeros(m)
            x_input[0] = cos(theta)
            x_input[1] = sin(theta)
            x_input = torch.tensor(x_input).float()
            y = mod(x_input)
            regularization += y**2 
        regularization *= mm / n2
        if gamma < 500:
            gamma = gamma * 1.01
        if mm < 500:
            mm = mm * 1.01

        #print loss
        print(k, " epoch, loss: ", loss.data[0].numpy())
        print(k, " epoch, regularization loss: ", regularization.data[0].numpy())
        print(k, " loss to real solution: ", cal_loss(mod))
        if cal_loss(the_model) < 0.0001:
            break

        loss += regularization

        optimizer.zero_grad()
        loss.backward()

        scheduler.step()
        optimizer.step()
    stop = time.time()
    print(stop - start)
